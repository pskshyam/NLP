# %%
import os
import re
import pandas as pd
import numpy as np

# %% [markdown]
# # Libraries for text preprocessing
# import re
# import nltk
# #nltk.download('stopwords')
# #from nltk.corpus import stopwords
# #from nltk.stem.porter import PorterStemmer
# #from nltk.tokenize import RegexpTokenizer
# #nltk.download('wordnet')
# #from nltk.stem.wordnet import WordNetLemmatizer

# %% [markdown]
# ##Creating a list of stop words and adding custom stopwords
# stop_words = set(stopwords.words("english"))
# print(stop_words)

# %%
##Creating a list of custom stopwords
#new_words = ["shall", "agreement", "service", "consultant", "may", "party", "customer", "work"]
#stop_words = stop_words.union(new_words)

# %%
def preprocess(text):
    #Preprocess                
    text = text.replace('\n',' ').lower()

    #Remove punctuations
    text = re.sub('[^a-z]', ' ', text)
    text = re.sub(r'\s+', ' ', text)

    ##Convert to list from string
    #text = text.split()

    ##Stemming
    #ps=PorterStemmer()

    #Lemmatisation
    #lem = WordNetLemmatizer()
    #text = [lem.lemmatize(word) for word in text if not word in  stop_words] 
    #text = " ".join(text)
    return text

# %%
path = '/home/user/Shyam/Code/Release_6.0/Dev/Snorkel/data/filtered/'
docs = []
filenames = []
labels = []

for root, dirs, files in os.walk(path):
    for file in files:
        with open (os.path.join(root+'/'+file), encoding='utf8') as f:            
            
            text = f.read()
            text = preprocess(text)                

            if 'msa' in root:
                docs.append(text)
                filenames.append(file)
                labels.append('MSA')            
            
            if 'sow' in root:
                docs.append(text)
                filenames.append(file)
                labels.append('SOW')
            
            if 'addendum' in root:
                docs.append(text)
                filenames.append(file)
                labels.append('Addendum')
                
            if 'nda' in root:
                docs.append(text)
                filenames.append(file)
                labels.append('NDA')
                
            if 'other' in root:
                docs.append(text)
                filenames.append(file)
                labels.append('Others')

print(len(docs))
# Out:
# 1400

# %%
df = pd.DataFrame(list(zip(filenames, docs, labels)), columns=['filename','text', 'label'])
df.head()
# Out:
#                   filename                                               text  \
# 0  D27186.pdf.out.html.txt  loch woltexs kinwer busines statement work dtm...
# 1  D12738.pdf.out.html.txt  amendment two outsource service agreement stat...
# 2  D27843.pdf.out.html.txt  addendum new schedule c pricing january wolter...
# 3  D04193.pdf.out.html.txt  addendum master service agreement addendum num...
# 4  D01834.pdf.out.html.txt  addendum toner contract agreement effective ap...
#
#       label
# 0  Addendum
# 1  Addendum
# 2  Addendum
# 3  Addendum
# 4  Addendum

# %%
df = pd.read_csv('labeled_data_new1.csv')
df.shape
# Out:
# (1397, 3)

# %%
df_msa = df[df.label == 'MSA']
df_msa.head()
# Out:
#                     filename  \
# 535  D04427.pdf.out.html.txt
# 536  D05236.pdf.out.html.txt
# 537  D00788.pdf.out.html.txt
# 538  D11628.pdf.out.html.txt
# 539  D06496.pdf.out.html.txt
#
#                                                   text label
# 535  master office supply supply agreement march ma...   MSA
# 536  dec quim brown ettiott j j cch columnist agree...   MSA
# 537  wolters kluwer business editorial service agre...   MSA
# 538  canon ai j canon financial service inc image p...   MSA
# 539  wed fax colour use lprepared l agreement made ...   MSA

# %%
df_addendum = df[df.label == 'Addendum']
df_addendum.head()
# Out:
#                   filename                                               text  \
# 0  D27186.pdf.out.html.txt  loch woltexs kinwer busines statement work dtm...
# 1  D12738.pdf.out.html.txt  amendment two outsource service agreement stat...
# 2  D27843.pdf.out.html.txt  addendum new schedule c pricing january wolter...
# 3  D04193.pdf.out.html.txt  addendum master service agreement addendum num...
# 4  D01834.pdf.out.html.txt  addendum toner contract agreement effective ap...
#
#       label
# 0  Addendum
# 1  Addendum
# 2  Addendum
# 3  Addendum
# 4  Addendum

# %%
df_sow = df[df.label == 'SOW']
df_sow.head()
# Out:
#                      filename  \
# 1002  D26831.pdf.out.html.txt
# 1003  D15231.pdf.out.html.txt
# 1004  D08418.pdf.out.html.txt
# 1005  D01666.pdf.out.html.txt
# 1006  D36616.pdf.out.html.txt
#
#                                                    text label
# 1002  resource scheduler workplace solution pilot st...   SOW
# 1003  statement work wolters kluwer financial servic...   SOW
# 1004  task order task order part consulting service ...   SOW
# 1005  mark statement work client wolters kluwer fina...   SOW
# 1006  form statement work statement work number stat...   SOW

# %%
df_nda = df[df.label == 'NDA']
df_nda.head()
# Out:
#                      filename  \
# 1266  D01627.pdf.out.html.txt
# 1267  D00944.pdf.out.html.txt
# 1268  D01117.pdf.out.html.txt
# 1269  D02010.pdf.out.html.txt
# 1270  D08781.pdf.out.html.txt
#
#                                                    text label
# 1266  mutual confidentiality agreement mutual confid...   NDA
# 1267  contract admin dec received mutual confidentia...   NDA
# 1268  contract admin aug wkfs use received mutual co...   NDA
# 1269  uesrme prepared dkg received mutual confidenti...   NDA
# 1270  x kfs use prepared mutual confidentiality non ...   NDA

# %%
df_others = df[df.label == 'Others']
df_others.head()
# Out:
#                     filename  \
# 278  D15596.pdf.out.html.txt
# 279  D15338.pdf.out.html.txt
# 280  D10525.pdf.out.html.txt
# 281  D13307.pdf.out.html.txt
# 282  D00254.pdf.out.html.txt
#
#                                                   text   label
# 278  date subject wolters kluwer nv zuidpoolsingel ...  Others
# 279  wolters kluwer nv zuidpoolsingel wolters kluwe...  Others
# 280  cch wolters kluwer business april mary paladin...  Others
# 281  wolters kluwer wolters kluwer nv tel zuidpools...  Others
# 282  wolters kluwer th avenue new york ny attn alfr...  Others

# %%
#Fetch wordcount for each doc
#df_msa['word_count'] = df_msa['text'].apply(lambda x: len(str(x).split(" ")))
#df_msa[['filename','word_count']].head()

df_others['word_count'] = df_others['text'].apply(lambda x: len(str(x).split(" ")))
df_others[['filename','word_count']].head()
# Out:
# /home/user/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
#                     filename  word_count
# 278  D15596.pdf.out.html.txt         102
# 279  D15338.pdf.out.html.txt         610
# 280  D10525.pdf.out.html.txt         179
# 281  D13307.pdf.out.html.txt         171
# 282  D00254.pdf.out.html.txt         507

# %%
df_others['word_count'].describe()
# Out:
# count      257.000000
# mean      1069.050584
# std       3272.845530
# min         48.000000
# 25%        133.000000
# 50%        302.000000
# 75%        701.000000
# max      45560.000000
# Name: word_count, dtype: float64

# %%
#Identify common words
freq = pd.Series(' '.join(df_others['text']).split()).value_counts()[:50]
freq
# Out:
# service        5683
# agreement      2905
# shall          2399
# sap            2207
# software       1913
# customer       1892
# kluwer         1746
# user           1710
# party          1678
# term           1660
# wolters        1657
# use            1619
# order          1480
# may            1468
# date           1414
# data           1400
# information    1313
# e              1217
# change         1203
# license        1126
# client         1075
# business       1074
# fee            1022
# b               981
# right           967
# system          919
# day             894
# v               881
# access          869
# product         864
# time            860
# page            855
# schedule        834
# support         830
# section         815
# number          810
# wageworks       795
# company         775
# management      768
# name            761
# provided        751
# c               751
# application     741
# per             730
# charge          730
# one             701
# com             699
# licensed        660
# form            654
# wk              631
# dtype: int64

# %%
#Identify uncommon words
freq1 =  pd.Series(' '.join(df_others['text']).split()).value_counts()[-30:]
freq1
# Out:
# netaccesschannel                                                                                                        1
# schweizerische                                                                                                          1
# eprocurement                                                                                                            1
# atid                                                                                                                    1
# scssssssssssessessssesssessssssvesssossussusssvesevesesssscssssecsuenscesecsusesscscesscencssavessonsseenavecusserse    1
# pensioner                                                                                                               1
# parrish                                                                                                                 1
# fekum                                                                                                                   1
# licensea                                                                                                                1
# mecaran                                                                                                                 1
# expiorer                                                                                                                1
# eei                                                                                                                     1
# pra                                                                                                                     1
# gummlne                                                                                                                 1
# probably                                                                                                                1
# marlcctlng                                                                                                              1
# counttersignature                                                                                                       1
# onverkort                                                                                                               1
# aqe                                                                                                                     1
# eyrt                                                                                                                    1
# respectfully                                                                                                            1
# prudent                                                                                                                 1
# enbhemer                                                                                                                1
# levitin                                                                                                                 1
# agreenient                                                                                                              1
# oq                                                                                                                      1
# wofkfow                                                                                                                 1
# resademyeom                                                                                                             1
# taschereau                                                                                                              1
# alv                                                                                                                     1
# dtype: int64

# %%
#view one doc
df_nda.text[1266]
# Out:
# 'mutual confidentiality agreement mutual confidentiality agreement agreement wolters kluwer united state inc half subsidiary division affiliated entity including subsidiary division affiliated entity company ca inc behalf ail subsidiary division affiliated entity together company party party entered january asa condition consideration party furnishing making available party certain confidential information hereafter defined party agree follows certain definition capitalized term set forth following respective meaning used agreement affiliate mean entity natural person directly indirectly one interme diary control controlled com mon control entity person specified affiliated entity mean corporation limited liability company partnership association entity affiliate confidential information includes formation reasonably stood confidential proprietary generally available public furnished made available behalf disclosing par ty receiving party representa tives whether furnished made available date agreement whether labeled otherwise identified confidential regardless form format medium mode disclosure written verbal visual electronic confidential information also includes written electronic report material rec ords document including copy thereof prepared receiving party representative based derived incorporat ing otherwise reflecting whole part information evaluation disclosing party shall refer party provid ing confidential information receiving par ty eyaluation mean assessment evaluation party ability provide responsive geods service meet request need party review analysis work undertaken connection party preparation fer proposal relating possible com mercial arrangement relationship agreement tween party performance mean receiving party per formance service provision good deliverable called definitive written agreement party accordance term condition thereof whether agreement nowor hereafter becomes effective recsiving party shall refer party provided confidential information disclos ing party representative either party mean direc tor officer partner employee temporary con tract personnel lender attorney accountant finan cial tax legal advisor agent representative party affiliated entity party ownership confidential information party remain exclusive property party without limiting generality foregoing li cense right use except expressly permitted right title interest copyright patent trademark trade name product name logo ather proprietary intellectual property right granted agreement disclosure hereunder confidentiality non disclosure non use obli gations receiving party acknowledges eco nomic value disclosing party confidential information disclosing party receiving party keep confidential information dis closing party confidential disclose ex cept extent expressly permitted agreement extent receiving party becomes aware breach agreement agrees inform disclosing party breach addition receiving party use permit use confidential infor mation disclosing party connection receiving party evaluation ii extent provided definitive writ ten agreement party receiving party performance agreement accord ance itsterms restrict disclosure confidential information disclosing party solely receiving party representative need know defined confidential information subject confidentiality non use obli gations substantially similar imposed agreement collectively authorized par tie advise authorized party gain access confidential information disclosing party confidential nature obligation spect confidential information make number copy confidential information disclosing party necessary disseminate confidential information au thorized party ensure confidentiality notice set forth confidential information reproduced full copy safeguard confidential information dis closing party least degree care avoid unauthorized disclosure receiving party us protect confidential infor mation le reasonable care responsible improper use disclosure confidential i ...

# %%
msa_corpus = df[df.label=='MSA'].text.values
sow_corpus = df[df.label=='SOW'].text.values
nda_corpus = df[df.label=='NDA'].text.values
addendum_corpus = df[df.label=='Addendum'].text.values
others_corpus = df[df.label=='Others'].text.values

# %%
corpus = [msa_corpus, sow_corpus, nda_corpus, addendum_corpus, others_corpus]

# %%
#Word cloud
from os import path
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import matplotlib.pyplot as plt
# %matplotlib inline
wordcloud = WordCloud(
                          background_color='white',
                          stopwords=stop_words,
                          max_words=100,
                          max_font_size=50, 
                          random_state=42
                         ).generate(str(corpus))
print(wordcloud)
fig = plt.figure(1)
plt.imshow(wordcloud)
plt.axis('off')
plt.show()
fig.savefig("word1.png", dpi=900)
# Out:
# <wordcloud.wordcloud.WordCloud object at 0x7f131f0b2b38>

# %%
from sklearn.feature_extraction.text import CountVectorizer

for corp in corpus:    
    top1_words = get_top_n_words(corp)
    top2_words = get_top_n2_words(corp)
    top3_words = get_top_n3_words(corp)
    top4_words = get_top_n4_words(corp)
    top5_words = get_top_n5_words(corp)
    top_words = pd.DataFrame(list(zip(top1_words, top2_words, top3_words, top4_words, top5_words)), columns=['Top1','Top2','Top3', 'Top4', 'Top5'])
    top_words.to_csv('top_words_new.csv', index=None)

# %%
#Create a vector of word counts using CountVectorizer
from sklearn.feature_extraction.text import CountVectorizer
import re
cv=CountVectorizer(max_df=0.6,stop_words=stop_words, max_features=10000, ngram_range=(1,3))
X=cv.fit_transform(corpus)

# %%
cv.vocabulary_
# Out:
# {'nv': 5757,
#  'zuidpoolsingel': 9995,
#  'ze': 9982,
#  'alphen': 472,
#  'aan': 1,
#  'den': 2495,
#  'rijn': 7379,
#  'box': 1096,
#  'ba': 898,
#  'netherlands': 5583,
#  'www': 9952,
#  'wolterskluwer': 9895,
#  'investis': 4443,
#  'limited': 4870,
#  'attn': 779,
#  'mr': 5451,
#  'fashion': 3375,
#  'street': 8551,
#  'london': 4962,
#  'united': 9240,
#  'kingdom': 4554,
#  'november': 5716,
#  'tel': 8868,
#  'inter': 4387,
#  'company': 1650,
#  'assignment': 717,
#  'wk': 9814,
#  'mail': 5020,
#  'mthompson': 5464,
#  'dear': 2389,
#  'letter': 4725,
#  'inform': 4252,
#  'hereby': 3868,
#  'assigns': 721,
#  'january': 4503,
#  'professional': 6646,
#  'sale': 7493,
#  'order': 5906,
#  'form': 3569,
#  'march': 5139,
#  'including': 4152,
#  'right': 7347,
#  'obligation': 5777,
#  'subsidiary': 8622,
#  'corporation': 1989,
#  'technology': 8846,
#  'sincerely': 8219,
#  'maarten': 5005,
#  'thompson': 8998,
#  'vice': 9556,
#  'president': 6516,
#  'general': 3703,
#  'counsel': 2006,
#  'secretary': 7736,
#  'chamber': 1368,
#  'commerce': 1624,
#  'date subject': 2340,
#  'subject wolters': 8589,
#  'kluwer nv': 4596,
#  'nv zuidpoolsingel': 5764,
#  'zuidpoolsingel ze': 9996,
#  'ze alphen': 9983,
#  'alphen aan': 473,
#  'aan den': 3,
#  'den rijn': 2497,
#  'rijn box': 7380,
#  'box ba': 1099,
#  'ba alphen': 899,
#  'rijn netherlands': 7382,
#  'netherlands www': 5589,
#  'www wolterskluwer': 9955,
#  'wolterskluwer com': 9896,
#  'attn mr': 783,
#  'united kingdom': 9241,
#  'november tel': 5721,
#  'tel inter': 8870,
#  'inter company': 4388,
#  'company assignment': 1651,
#  'assignment wk': 718,
#  'agreement mail': 366,
#  'mail mthompson': 5026,
#  'mthompson wolterskluwer': 5465,
#  'com dear': 1590,
#  'dear mr': 2390,
#  'letter inform': 4726,
#  'inform wolters': 4253,
#  'nv wolters': 5762,
#  'kluwer hereby': 4579,
#  'hereby assigns': 3870,
#  'assigns january': 722,
#  'january professional': 4506,
#  'professional service': 6651,
#  'service agreement': 7847,
#  'agreement wolters': 424,
#  'sale order': 7498,
#  'order form': 5930,
#  'form wolters': 3581,
#  'including right': 4159,
#  'right obligation': 7363,
#  'obligation subsidiary': 5782,
#  'subsidiary corporation': 8624,
#  'corporation wolters': 1990,
#  'kluwer technology': 4606,
#  'technology sincerely': 8854,
#  'sincerely maarten': 8220,
#  'maarten thompson': 5006,
#  'thompson vice': 8999,
#  'vice president': 9557,
#  'president general': 6517,
#  'general counsel': 3707,
#  'counsel company': 2007,
#  'company secretary': 1661,
#  'secretary wolters': 7737,
#  'nv page': 5760,
#  'page chamber': 6046,
#  'chamber commerce': 1369,
#  'date subject wolters': 2341,
#  'subject wolters kluwer': 8590,
#  'wolters kluwer nv': 9882,
#  'kluwer nv zuidpoolsingel': 4599,
#  'nv zuidpoolsingel ze': 5765,
#  'zuidpoolsingel ze alphen': 9997,
#  'ze alphen aan': 9984,
#  'alphen aan den': 474,
#  'aan den rijn': 4,
#  'den rijn box': 2498,
#  'rijn box ba': 7381,
#  'box ba alphen': 1100,
#  'ba alphen aan': 900,
#  'den rijn netherlands': 2499,
#  'rijn netherlands www': 7384,
#  'netherlands www wolterskluwer': 5591,
#  'www wolterskluwer com': 9956,
#  'november tel inter': 5722,
#  'tel inter company': 8871,
#  'inter company assignment': 4389,
#  'company assignment wk': 1652,
#  'agreement mail mthompson': 367,
#  'mail mthompson wolterskluwer': 5027,
#  'mthompson wolterskluwer com': 5466,
#  'wolterskluwer com dear': 9897,
#  'com dear mr': 1591,
#  'letter inform wolters': 4727,
#  'inform wolters kluwer': 4254,
#  'kluwer nv wolters': 4598,
#  'nv wolters kluwer': 5763,
#  'wolters kluwer hereby': 9875,
#  'kluwer hereby assigns': 4580,
#  'hereby assigns january': 3871,
#  'assigns january professional': 724,
#  'january professional service': 4507,
#  'professional service agreement': 6652,
#  'service agreement wolters': 7860,
#  'agreement wolters kluwer': 425,
#  'sale order form': 7499,
#  'order form wolters': 5935,
#  'form wolters kluwer': 3582,
#  'including right obligation': 4160,
#  'right obligation subsidiary': 7366,
#  'obligation subsidiary corporation': 5783,
#  'subsidiary corporation wolters': 8625,
#  'corporation wolters kluwer': 1991,
#  'wolters kluwer technology': 9888,
#  'kluwer technology sincerely': 4610,
#  'technology sincerely maarten': 8855,
#  'sincerely maarten thompson': 8221,
#  'maarten thompson vice': 5007,
#  'thompson vice president': 9000,
#  'vice president general': 9558,
#  'president general counsel': 6518,
#  'general counsel company': 3708,
#  'counsel company secretary': 2008,
#  'company secretary wolters': 1662,
#  'secretary wolters kluwer': 7738,
#  'kluwer nv page': 4597,
#  'nv page chamber': 5761,
#  'page chamber commerce': 6047,
#  'reference': 7045,
#  'version': 9525,
#  'table': 8761,
#  'content': 1888,
#  'security': 7770,
#  'cee': 1322,
#  'bd': 992,
#  'ee': 2881,
#  'eee': 2885,
#  'rep': 7171,
#  'ot': 5978,
#  'consequence': 1829,
#  'go': 3753,
#  'cc': 1301,
#  'confidentiality': 1774,
#  'document': 2705,
#  'contains': 1886,
#  'information': 4255,
#  'property': 6710,
#  'confidential': 1763,
#  'system': 8742,
#  'submitted': 8599,
#  'basis': 984,
#  'must': 5481,
#  'used': 9381,
#  'way': 9694,
#  'disclosed': 2634,
#  'party': 6106,
#  'either': 2911,
#  'whole': 9741,
#  'part': 6084,
#  'except': 3213,
#  'employee': 2954,
#  'affiliate': 275,
#  'advisor': 257,
#  'purpose': 6845,
#  'instance': 4348,
#  'prior': 6578,
#  'written': 9942,
#  'consent': 1821,
#  'obtained': 5785,
#  'otherwise': 5981,
#  'nederland': 5555,
#  'ol': 5815,
#  'schedule': 7649,
#  'audit': 794,
#  'nl': 5648,
#  'non': 5651,
#  'sap': 7528,
#  'hosting': 3946,
#  'clean': 1504,
#  'objective': 5775,
#  'set': 8040,
#  'forth': 3592,
#  'procedure': 6604,
#  'pursuant': 6855,
#  'clause': 1503,
#  'master': 5157,
#  'section': 7739,
#  'whether': 9733,
#  'complies': 1692,
#  'scope': 7704,
#  'request': 7213,
#  'independent': 4204,
#  'certified': 1361,
#  'auditor': 797,
#  'hereinafter': 3881,
#  'referred': 7052,
#  'mutual': 5488,
#  'periodically': 6300,
#  'perform': 6261,
#  'respect': 7273,
#  'effort': 2901,
#  'review': 7337,
#  'maintain': 5039,
#  'enforce': 3004,
#  'others': 5980,
#  'though': 9002,
#  'established': 3150,
#  'preventing': 6523,
#  'unauthorized': 9213,
#  'use': 9319,
#  'principle': 6564,
#  'allowed': 465,
#  'one': 5822,
#  'per': 6224,
#  'contract': 1899,
#  'year': 9969,
#  'event': 3190,
#  'incident': 4123,
#  'occurs': 5794,
#  'time': 9021,
#  'additional': 179,
#  'respective': 7279,
#  'shall': 8071,
#  'act': 135,
#  'single': 8222,
#  'point': 6431,
#  'contact': 1860,
#  'regarding': 7066,
#  'manager': 5117,
#  'governance': 3764,
#  'officer': 5804,
#  'mutually': 5490,
#  'agree': 308,
#  'upon': 9281,
#  'capable': 1251,
#  'performing': 6286,
#  'agreed': 312,
#  'auditing': 796,
#  'activity': 154,
#  'manner': 5128,
#  'experience': 3295,
#  'specifically': 8408,
#  'complexity': 1686,
#  'together': 9061,
#  'start': 8479,
#  'model': 5372,
#  'criterion': 2090,
#  'concerning': 1725,
#  'needed': 5565,
#  'infrastructure': 4302,
#  'deliverable': 2472,
#  'make': 5061,
#  'sure': 8708,
#  'comply': 1693,
#  'rule': 7451,
#  'conduct': 1758,
#  'investigation': 4442,
#  'cause': 1295,
#  'disruption': 2675,
#  'normal': 5676,
#  'business': 1143,
#  'actively': 153,
#  'support': 8673,
#  'reasonable': 6992,
#  'lead': 4689,
#  'report': 7180,
#  'send': 7792,
#  'final': 3468,
#  'draft': 2761,
#  'receipt': 7002,
#  'four': 3603,
#  'week': 9714,
#  'execution': 3259,
#  'consist': 1835,
#  'comment': 1623,
#  'present': 6512,
#  'joint': 4518,
#  'meeting': 5284,
#  'mentioned': 5291,
#  'within': 9781,
#  'period': 6288,
#  'presentation': 6513,
#  'measure': 5267,
#  'take': 8796,
#  'ii': 4051,
#  'implement': 4075,
#  'iii': 4057,
#  'cost': 2002,
#  'implementing': 4082,
#  'borne': 1093,
#  'based': 957,
#  'finding': 3490,
#  'position': 6452,
#  'fail': 3362,
#  'reach': 6979,
#  'refer': 7044,
#  'dispute': 2667,
#  'bear': 993,
#  'place': 6361,
#  'result': 7302,
#  'found': 3601,
#  'responsible': 7290,
#  'question': 6907,
#  'responsibility': 7289,
#  'shared': 8156,
#  'pro': 6596,
#  'rata': 6942,
#  'table content': 8764,
#  'eee eee': 2886,
#  'whole part': 9742,
#  'employee employee': 2959,
#  'prior written': 6584,
#  'written consent': 9946,
#  'system nederland': 8754,
#  'security audit': 7771,
#  'system nl': 8756,
#  'non sap': 5660,
#  'sap hosting': 7579,
#  'hosting service': 3955,
#  'set forth': 8042,
#  'kluwer system': 4604,
#  'master agreement': 5158,
#  'agreement section': 397,
#  'section non': 7752,
#  'security auditor': 7772,
#  'hereinafter referred': 3882,
#  'mutual agreement': 5489,
#  'unauthorized use': 9216,
#  'contract year': 1919,
#  'security incident': 7773,
#  'party shall': 6152,
#  'point contact': 6432,
#  'mutually agree': 5491,
#  'agreement party': 378,
#  'use respect': 9349,
#  'respect subject': 7277,
#  'kluwer shall': 4603,
#  'shall make': 8121,
#  'normal business': 5677,
#  'audit shall': 795,
#  'shall comply': 8086,
#  'security report': 7775,
#  'execution version': 3262,
#  'report shall': 7188,
#  'shall consist': 8088,
#  'mutually agreed': 5492,
#  'agreed upon': 315,
#  'shall borne': 8081,
#  'party respective': 6147,
#  'take place': 8797,
#  'shall bear': 8079,
#  'party party': 6138,
#  'pro rata': 6597,
#  'rata basis': 6943,
#  'prior written consent': 6586,
#  'non sap hosting': 5663,
#  'sap hosting service': 7580,
#  'hosting service agreement': 3956,
#  'wolters kluwer system': 9886,
#  'wolters kluwer shall': 9885,
#  'mutually agreed upon': 5493,
#  'pro rata basis': 6598,
#  'cch': 1303,
#  'april': 676,
#  'avenue': 883,
#  'white': 9737,
#  'ny': 5767,
#  'knowledge': 4624,
#  'health': 3851,
#  'care': 1264,
#  'entity': 3070,
#  'guide': 3799,
#  'work': 9902,
#  'email': 2939,
#  'discussion': 2660,
#  'february': 3392,
#  'terminate': 8933,
#  'certain': 1354,
#  'publishing': 6830,
#  'dated': 2349,
#  'june': 4532,
#  'amended': 492,
#  'collectively': 1581,
#  'liability': 4762,
#  'thereunder': 8978,
#  'behalf': 999,
#  'successor': 8633,
#  'release': 7115,
#  'thereto': 8975,
#  'existing': 3278,
#  'future': 3667,
#  'claim': 1485,
#  'demand': 2494,
#  'debt': 2397,
#  'expense': 3288,
#  'damage': 2213,
#  'judgment': 4525,
#  'whatever': 9727,
#  'kind': 4553,
#  'nature': 5545,
#  'law': 4675,
#  'equity': 3109,
#  'known': 4629,
#  'arising': 688,
#  'directly': 2622,
#  'indirectly': 4231,
#  'arise': 686,
#  'enforcement': 3007,
#  'termination': 8942,
#  'please': 6400,
#  'con': 1712,
#  'rm': 7395,
#  'foregoing': 3566,
#  'signing': 8211,
#  'two': 9187,
#  'copy': 1965,
#  'returning': 7328,
#  'enclosed': 2985,
#  'prepaid': 6506,
#  'envelope': 3080,
#  'thirty': 8993,
#  'day': 2353,
#  'hereof': 3885,
#  'countersign': 2016,
#  'return': 7322,
#  'original': 5972,
#  'le': 4687,
#  'note': 5686,
#  'sign': 8179,
#  'also': 476,
#  'expressly': 3325,
#  'communicate': 1642,
#  'writing': 9939,
#  'constitute': 1841,
#  'concern': 1723,
#  'hesitate': 3893,
#  'thank': 8967,
#  'prompt': 6698,
#  'attention': 776,
#  'matter': 5179,
#  'title': 9051,
#  'accepted': 44,
#  'author': 808,
#  'kluwer business': 4564,
#  'knowledge based': 4626,
#  'based audit': 958,
#  'health care': 3852,
#  'agreement dated': 341,
#  'collectively agreement': 1582,
#  'party agreement': 6111,
#  'agreement shall': 400,
#  'successor assigns': 8634,
#  'claim demand': 1488,
#  'law equity': 4677,
#  'party may': 6132,
#  'directly indirectly': 2623,
#  'agreement except': 351,
#  'claim may': 1490,
#  'letter please': 4728,
#  'con rm': 1721,
#  'agreement foregoing': 353,
#  'within thirty': 9794,
#  'thirty day': 8994,
#  'day date': 2357,
#  'upon receipt': 9289,
#  'please note': 6409,
#  'sign return': 8182,
#  'letter within': 4731,
#  'day period': 2369,
#  'within time': 9796,
#  'time shall': 9039,
#  'shall also': 8073,
#  'agreement term': 414,
#  'please hesitate': 6407,
#  'hesitate contact': 3894,
#  'prompt attention': 6699,
#  'business name': 1160,
#  'wolters kluwer business': 9865,
#  'knowledge based audit': 4627,
#  'within thirty day': 9795,
#  'thirty day date': 8995,
#  'please hesitate contact': 6408,
#  'fax': 3379,
#  'po': 6426,
#  'info': 4249,
#  'hewlett': 3911,
#  'packard': 6033,
#  'managing': 5126,
#  'director': 2624,
#  'ar': 681,
#  'amsterdam': 514,
#  'hp': 3984,
#  'th': 8962,
#  'july': 4529,
#  'rd': 6973,
#  'transfer': 9139,
#  'understand': 9222,
#  'entered': 3046,
#  'hand': 3826,
#  'group': 3788,
#  'assigned': 714,
#  'split': 8431,
#  'subsequently': 8621,
#  'partially': 6091,
#  'trust': 9173,
#  'initiative': 4326,
#  'well': 9721,
#  'action': 138,
#  'undertaken': 9227,
#  'latter': 4671,
#  'regard': 7065,
#  'advance': 246,
#  'wim': 9757,
#  'weima': 9719,
#  'kluwer wolters': 4619,
#  'po box': 6427,
#  'info wolterskluwer': 4250,
#  'hewlett packard': 3912,
#  'nederland attn': 5556,
#  'agreement entered': 347,
#  'nederland wolters': 5560,
#  'wim weima': 9758,
#  'wolters kluwer wolters': 9890,
#  'kluwer wolters kluwer': 4620,
#  'info wolterskluwer com': 4251,
#  'new': 5613,
#  'york': 9977,
#  'phone': 6339,
#  'legal': 4711,
#  'quotation': 6912,
#  'quote': 6914,
#  'created': 2080,
#  'expires': 3310,
#  'tom': 9066,
#  'payment': 6189,
#  'net': 5578,
#  'credit': 2087,
#  'approval': 662,
#  'submit': 8596,
#  'purchase': 6833,
#  'jay': 4508,
#  'rr': 7434,
#  'ro': 7398,
#  'shipping': 8171,
#  'handling': 3829,
#  'total': 9084,
#  'estimated': 3154,
#  'delivery': 2477,
#  'entry': 3079,
#  'method': 5303,
#  'standard': 8458,
#  'duty': 2818,
#  'paid': 6065,
#  'special': 8399,
#  'exempt': 3266,
#  'print': 6565,
#  'pm': 6420,
#  'number': 5730,
#  'solution': 8363,
#  'item': 4490,
#  'offered': 5801,
#  'defined': 2429,
#  'configuration': 1775,
#  'adjustment': 234,
#  'changing': 1405,
#  'affect': 273,
#  'offer': 5800,
#  'saas': 7480,
#  'qc': 6872,
#  'base': 943,
#  'product': 6625,
#  'svc': 8717,
#  'fee': 3398,
#  'inc': 4102,
#  'usr': 9455,
#  'yr': 9979,
#  'sw': 8724,
#  'quality': 6896,
#  'center': 1323,
#  'software': 8267,
#  'region': 7069,
#  'country': 2019,
#  'discount': 2644,
#  'concurrent': 1729,
#  'user': 9388,
#  'defect': 2424,
#  'proprietary': 6717,
#  'share': 8155,
#  'charge': 1417,
#  'stated': 8503,
#  'separately': 7815,
#  'transportation': 9161,
#  'included': 4143,
#  'price': 6527,
#  'quoted': 6926,
#  'tax': 8815,
#  'applicable': 588,
#  'partial': 6090,
#  'shipment': 8169,
#  'considered': 1834,
#  'acceptable': 34,
#  'unless': 9251,
#  'noted': 5692,
#  'usa': 9308,
#  'end': 2987,
#  'condition': 1733,
#  'managed': 5081,
#  'statement': 8504,
#  'ct': 2110,
#  'hardware': 3837,
#  'pass': 6167,
#  'named': 5529,
#  'destination': 2562,
#  'sequence': 7817,
#  'resulting': 7307,
#  'requested': 7224,
#  'telephone': 8876,
#  'individual': 4232,
#  'call': 1230,
#  'identifier': 4039,
#  'handle': 3827,
#  'previously': 6526,
#  'purchased': 6839,
#  'herein': 3877,
#  'installed': 4347,
#  'representative': 7203,
#  'technical': 8838,
#  'financing': 3488,
#  'option': 5892,
#  'finance': 3478,
#  'canada': 1242,
#  'lease': 4699,
#  'exclusive': 3243,
#  'value': 9480,
#  'added': 172,
#  'appear': 580,
#  'separate': 7810,
#  'invoice': 4445,
#  'ensure': 3042,
#  'appropriate': 657,
#  'valid': 9473,
#  'exemption': 3270,
#  'certificate': 1358,
#  'referencing': 7049,
#  'vendor': 9505,
#  'processing': 6616,
#  'california': 1229,
#  'requires': 7245,
#  'collection': 1580,
#  'laptop': 4657,
#  'computer': 1710,
#  'desktop': 2559,
#  'monitor': 5392,
#  'reflected': 7057,
#  'new york': 5622,
#  'york ny': 9978,
#  'phone fax': 6341,
#  'fax email': 3380,
#  'payment term': 6208,
#  'term net': 8918,
#  'net day': 5579,
#  'credit approval': 2088,
#  'purchase order': 6835,
#  'email jay': 2941,
#  'shipping handling': 8172,
#  'print date': 6566,
#  'date pm': 2327,
#  'quote number': 6922,
#  'may affect': 5193,
#  'hp saas': 3990,
#  'saas qc': 7481,
#  'qc base': 6873,
#  'base product': 951,
#  'product svc': 6636,
#  'svc hp': 8720,
#  'usr yr': 9456,
#  'yr sw': 9980,
#  'sw svc': 8727,
#  'qc quality': 6875,
#  'quality center': 6898,
#  'center software': 1329,
#  'region country': 7070,
#  'country discount': 2022,
#  'discount hp': 2647,
#  'concurrent user': 1732,
#  'user region': 9429,
#  'confidential proprietary': 1768,
#  'proprietary information': 6718,
#  'price quoted': 6533,
#  'tax applicable': 8817,
#  'unless otherwise': 9254,
#  'purchase agreement': 6834,
#  'agreement price': 383,
#  'term condition': 8893,
#  'condition set': 1751,
#  'managed service': 5095,
#  'statement work': 8505,
#  'agreement number': 373,
#  'following information': 3557,
#  'delivery date': 2478,
#  'name telephone': 5516,
#  'telephone number': 8880,
#  'number individual': 5746,
#  'end user': 2993,
#  'product support': 6635,
#  'support agreement': 8674,
#  'please contact': 6404,
#  'sale representative': 7503,
#  'technology solution': 8856,
#  'value added': 9481,
#  'applicable tax': 603,
#  'sale tax': 7504,
#  'fee may': 3414,
#  'new york ny': 5623,
#  'phone fax email': 6342,
#  'payment term net': 6209,
#  'hp saas qc': 3991,
#  'saas qc base': 7482,
#  'qc base product': 6874,
#  'base product svc': 952,
#  'product svc hp': 6637,
#  'svc hp saas': 8721,
#  'usr yr sw': 9457,
#  'yr sw svc': 9981,
#  'sw svc hp': 8728,
#  'saas qc quality': 7483,
#  'qc quality center': 6876,
#  'quality center software': 6899,
#  'region country discount': 7071,
#  'country discount hp': 2023,
#  'discount hp saas': 2648,
#  'user region country': 9430,
#  'confidential proprietary information': 1769,
#  'term condition set': 8904,
#  'condition set forth': 1752,
#  'value added tax': 9482,
#  'autonomy': 843,
#  'peter': 6329,
#  'dupain': 2808,
#  'nieuwegein': 5641,
#  'december': 2401,
#  'verity': 9518,
#  'benelux': 1022,
#  'license': 4775,
#  'amendment': 494,
#  'cd': 1312,
#  'web': 9696,
#  'publisher': 6825,
#  'ofjune': 5805,
#  'peter dupain': 6330,
#  'december tel': 2404,
#  'mr dupain': 5454,
#  'january following': 4504,
#  'following agreement': 3550,
#  'verity benelux': 9519,
#  'technology master': 8850,
#  'user software': 9441,
#  'software license': 8288,
#  'license agreement': 4776,
#  'agreement may': 370,
#  'including amendment': 4153,
#  'amendment thereunder': 497,
#  'verity cd': 9520,
#  'cd web': 1314,
#  'web publisher': 9705,
#  'publisher software': 6826,
#  'agreement ofjune': 374,
#  'agreement november': 371,
#  'november sincerely': 5719,
#  'december tel inter': 2405,
#  'dear mr dupain': 2392,
#  'assigns january following': 723,
#  'january following agreement': 4505,
#  'following agreement wolters': 3551,
#  'kluwer technology master': 4608,
#  'end user software': 3000,
#  'user software license': 9442,
#  'software license agreement': 8289,
#  'verity cd web': 9521,
#  'cd web publisher': 1315,
#  'web publisher software': 9706,
#  'publisher software license': 6827,
#  'service agreement november': 7854,
#  'agreement november sincerely': 372,
#  'november sincerely maarten': 5720,
#  'annex': 546,
#  'retro': 7319,
#  'transition': 9147,
#  'plan': 6364,
#  'newtel': 5630,
#  'essence': 3141,
#  'field': 3451,
#  'communication': 1645,
#  'management': 5096,
#  'approach': 656,
#  'description': 2537,
#  'commitment': 1632,
#  'establish': 3149,
#  'effective': 2893,
#  'working': 9921,
#  'relationship': 7110,
#  'provider': 6765,
#  'taking': 8802,
#  'provided': 6744,
#  'operation': 5876,
#  'related': 7092,
#  'since': 8218,
#  'performance': 6276,
#  'route': 7424,
#  'typically': 9205,
#  'include': 4136,
#  'contractual': 1926,
#  'facilitate': 3355,
#  'importance': 4089,
#  'reason': 6991,
#  'fully': 3650,
#  'co': 1565,
#  'operate': 5869,
#  'elsewhere': 2937,
#  'development': 2588,
#  'strategy': 8546,
#  'therefore': 8972,
#  'integral': 4363,
#  'pertaining': 6328,
#  'relevant': 7122,
#  'format': 3584,
#  'contained': 1878,
#  'explicitly': 3313,
#  'de': 2379,
#  'ne': 5551,
#  'occur': 5791,
#  'natural': 5543,
#  'exercise': 3271,
#  'breach': 1119,
#  'phase': 6332,
#  'depend': 2511,
#  'applies': 641,
#  'intent': 4386,
#  'alternative': 486,
#  'complete': 1676,
#  'similarly': 8215,
#  'detail': 2566,
#  'different': 2610,
#  'engagement': 3016,
#  'made': 5016,
#  'available': 860,
#  'third': 8979,
#  'process': 6609,
#  'handled': 3828,
#  'help': 3859,
#  'level': 4734,
#  'provide': 6733,
#  'continued': 1892,
#  'extend': 3329,
#  'completion': 1681,
#  'scale': 7644,
#  'case': 1279,
#  'extension': 3338,
#  'exceed': 3209,
#  'maximum': 5182,
#  'calendar': 1225,
#  'month': 5398,
#  'invoiced': 4450,
#  'accordance': 93,
#  'undersigned': 9221,
#  'duly': 2803,
#  'registered': 7074,
#  'ce': 1319,
#  'represented': 7207,
#  'office': 5803,
#  'vianen': 9551,
#  'whereas': 9730,
#  'provision': 6796,
#  'eld': 2915,
#  'providing': 6791,
#  'ned': 5554,
#  'article': 694,
#  'hereunder': 3887,
#  'terminated': 8937,
#  'speci': 8396,
#  'ed': 2852,
#  'effect': 2887,
#  'provides': 6788,
#  'critical': 2091,
#  'application': 606,
#  'af': 264,
#  'liates': 4769,
#  'seek': 7780,
#  'another': 563,
#  'cut': 2206,
#  'change': 1371,
#  'achieved': 120,
#  'series': 7821,
#  'cooperation': 1960,
#  'reasonably': 6997,
#  'required': 7233,
#  'contributing': 1933,
#  'wish': 9777,
#  'record': 7021,
#  'moment': 5387,
#  'thereafter': 8971,
#  'follows': 3560,
#  'definition': 2445,
#  'determined': 2580,
#  'cease': 1320,
#  'operational': 5877,
#  'continue': 1891,
#  'data': 2224,
#  'destruction': 2565,
#  'authorization': 821,
#  'noti': 5695,
#  'cation': 1294,
#  'cooperate': 1959,
#  'risk': 7389,
#  'actually': 161,
#  'occurred': 5792,
#  'resume': 7310,
#  'rst': 7437,
#  'planning': 6382,
#  'milestone': 5333,
#  'planned': 6375,
#  'civil': 1483,
#  'code': 1570,
#  'default': 2421,
#  'without': 9797,
#  'give': 3735,
#  'notice': 5698,
#  'entitled': 3068,
#  'adjust': 232,
#  'discus': 2658,
#  'validate': 9474,
#  'budget': 1133,
#  'revised': 7339,
#  'accordingly': 101,
#  'prejudice': 6497,
#  'documentation': 2719,
#  'detailed': 2571,
#  'create': 2078,
#  'execute': 3250,
#  'transport': 9160,
#  'export': 3315,
#  'database': 2274,
#  'availability': 844,
#  'project': 6673,
#  'leader': 4690,
#  'executed': 3251,
#  'consultant': 1849,
#  'skill': 8250,
#  'acknowledges': 126,
#  'preceding': 6493,
#  'site': 8236,
#  ...}

# %%
#Most frequently occuring uni-grams
def get_top_n_words(corpus, n=None):
    vec = CountVectorizer().fit(corpus)
    bag_of_words = vec.transform(corpus)
    sum_words = bag_of_words.sum(axis=0) 
    words_freq = [(word, sum_words[0, idx]) for word, idx in      
                   vec.vocabulary_.items()]
    words_freq =sorted(words_freq, key = lambda x: x[1], 
                       reverse=True)
    return words_freq[:n]
"""
#Convert most freq words to dataframe for plotting bar plot
top_words = get_top_n_words(corpus, n=20)
top_df = pd.DataFrame(top_words)
top_df.columns=["Word", "Freq"]

#Barplot of most freq words
import seaborn as sns
sns.set(rc={'figure.figsize':(13,8)})
g = sns.barplot(x="Word", y="Freq", data=top_df)
g.set_xticklabels(g.get_xticklabels(), rotation=30)"""
# Out:
# '\n#Convert most freq words to dataframe for plotting bar plot\ntop_words = get_top_n_words(corpus, n=20)\ntop_df = pd.DataFrame(top_words)\ntop_df.columns=["Word", "Freq"]\n\n#Barplot of most freq words\nimport seaborn as sns\nsns.set(rc={\'figure.figsize\':(13,8)})\ng = sns.barplot(x="Word", y="Freq", data=top_df)\ng.set_xticklabels(g.get_xticklabels(), rotation=30)'

# %%
#Most frequently occuring Bi-grams
def get_top_n2_words(corpus, n=None):
    vec1 = CountVectorizer(ngram_range=(2,2),  
            max_features=2000).fit(corpus)
    bag_of_words = vec1.transform(corpus)
    sum_words = bag_of_words.sum(axis=0) 
    words_freq = [(word, sum_words[0, idx]) for word, idx in     
                  vec1.vocabulary_.items()]
    words_freq =sorted(words_freq, key = lambda x: x[1], 
                reverse=True)
    return words_freq[:n]
"""
top2_words = get_top_n2_words(corpus, n=20)
top2_df = pd.DataFrame(top2_words)
top2_df.columns=["Bi-gram", "Freq"]
#print(top2_df)

#Barplot of most freq Bi-grams
import seaborn as sns
sns.set(rc={'figure.figsize':(13,8)})
h=sns.barplot(x="Bi-gram", y="Freq", data=top2_df)
h.set_xticklabels(h.get_xticklabels(), rotation=45)"""
# Out:
# '\ntop2_words = get_top_n2_words(corpus, n=20)\ntop2_df = pd.DataFrame(top2_words)\ntop2_df.columns=["Bi-gram", "Freq"]\n#print(top2_df)\n\n#Barplot of most freq Bi-grams\nimport seaborn as sns\nsns.set(rc={\'figure.figsize\':(13,8)})\nh=sns.barplot(x="Bi-gram", y="Freq", data=top2_df)\nh.set_xticklabels(h.get_xticklabels(), rotation=45)'

# %%
#Most frequently occuring Tri-grams
def get_top_n3_words(corpus, n=None):
    vec1 = CountVectorizer(ngram_range=(3,3), 
           max_features=2000).fit(corpus)
    bag_of_words = vec1.transform(corpus)
    sum_words = bag_of_words.sum(axis=0) 
    words_freq = [(word, sum_words[0, idx]) for word, idx in     
                  vec1.vocabulary_.items()]
    words_freq =sorted(words_freq, key = lambda x: x[1], 
                reverse=True)
    return words_freq[:n]
"""
top3_words = get_top_n3_words(corpus, n=20)
top3_df = pd.DataFrame(top3_words)
top3_df.columns=["Tri-gram", "Freq"]
#print(top3_df)

#Barplot of most freq Tri-grams
import seaborn as sns
sns.set(rc={'figure.figsize':(13,8)})
j=sns.barplot(x="Tri-gram", y="Freq", data=top3_df)
j.set_xticklabels(j.get_xticklabels(), rotation=45)"""
# Out:
# '\ntop3_words = get_top_n3_words(corpus, n=20)\ntop3_df = pd.DataFrame(top3_words)\ntop3_df.columns=["Tri-gram", "Freq"]\n#print(top3_df)\n\n#Barplot of most freq Tri-grams\nimport seaborn as sns\nsns.set(rc={\'figure.figsize\':(13,8)})\nj=sns.barplot(x="Tri-gram", y="Freq", data=top3_df)\nj.set_xticklabels(j.get_xticklabels(), rotation=45)'

# %%
def get_top_n4_words(corpus, n=None):
    vec1 = CountVectorizer(ngram_range=(4,4), 
           max_features=2000).fit(corpus)
    bag_of_words = vec1.transform(corpus)
    sum_words = bag_of_words.sum(axis=0) 
    words_freq = [(word, sum_words[0, idx]) for word, idx in     
                  vec1.vocabulary_.items()]
    words_freq =sorted(words_freq, key = lambda x: x[1], 
                reverse=True)
    return words_freq[:n]

# %%
def get_top_n5_words(corpus, n=None):
    vec1 = CountVectorizer(ngram_range=(5,5), 
           max_features=2000).fit(corpus)
    bag_of_words = vec1.transform(corpus)
    sum_words = bag_of_words.sum(axis=0) 
    words_freq = [(word, sum_words[0, idx]) for word, idx in     
                  vec1.vocabulary_.items()]
    words_freq =sorted(words_freq, key = lambda x: x[1], 
                reverse=True)
    return words_freq[:n]

# %%
top1_words = get_top_n_words(corpus)
top2_words = get_top_n2_words(corpus)
top3_words = get_top_n3_words(corpus)
top_words = pd.DataFrame(list(zip(top1_words, top2_words, top3_words)), columns=['Top1','Top2','Top3'])
top_words.head()
# Out:
#                 Top1                      Top2  \
# 0    (service, 5683)    (wolters kluwer, 1601)
# 1  (agreement, 2905)        (third party, 528)
# 2      (shall, 2399)     (term condition, 465)
# 3        (sap, 2207)  (service agreement, 460)
# 4   (software, 1913)   (service provider, 336)
#
#                                Top3
# 0  (wolters kluwer technology, 192)
# 1          (wolters kluwer nv, 135)
# 2           (sap business one, 122)
# 3             (alphen aan den, 121)
# 4               (aan den rijn, 120)

# %%
top_words.to_csv('top_words_others.csv', index=None)

# %% [markdown]
# #Converting to a matrix of integers with TF-IDF
# from sklearn.feature_extraction.text import TfidfTransformer
#
# tfidf_transformer=TfidfTransformer(smooth_idf=True,use_idf=True)
# tfidf_transformer.fit(X)
#
# # get feature names
# feature_names=cv.get_feature_names()
#
# # fetch document for which keywords needs to be extracted
# doc=corpus[402]
#
# #generate tf-idf for the given document
# tf_idf_vector=tfidf_transformer.transform(cv.transform([doc]))

# %% [markdown]
# #Function for sorting tf_idf in descending order
# from scipy.sparse import coo_matrix
#
# def sort_coo(coo_matrix):
#     tuples = zip(coo_matrix.col, coo_matrix.data)
#     return sorted(tuples, key=lambda x: (x[1], x[0]), reverse=True)
#
# def extract_topn_from_vector(feature_names, sorted_items, topn=10):
#     """get the feature names and tf-idf score of top n items"""
#
#     #use only topn items from vector
#     sorted_items = sorted_items[:topn]
#
#     score_vals = []
#     feature_vals = []
#
#     # word index and corresponding tf-idf score
#     for idx, score in sorted_items:
#
#         #keep track of feature name and its corresponding score
#         score_vals.append(round(score, 3))
#         feature_vals.append(feature_names[idx])
#
#     #create a tuples of feature,score
#     #results = zip(feature_vals,score_vals)
#     results= {}
#     for idx in range(len(feature_vals)):
#         results[feature_vals[idx]]=score_vals[idx]
#
#     return results
#
# #sort the tf-idf vectors by descending order of scores
# sorted_items=sort_coo(tf_idf_vector.tocoo())
#
# #extract only the top n; n here is 10
# keywords=extract_topn_from_vector(feature_names,sorted_items,5)
#
# # now print the results
# print("\nAbstract:")
# print(doc)
# print("\nKeywords:")
# for k in keywords:
#     print(k,keywords[k])

# %%
from snorkel.labeling import LabelingFunction
from snorkel.labeling import labeling_function
from snorkel.labeling import PandasLFApplier

msa_keywords = ['set forth section', 'meaning set forth', 'including without limitation', 
                'prior written consent', 'without prior written', 'intellectual industrial property', 
                'industrial property right', 'intellectual property right',  'privacy restricted data', 
                'prior written notice', 'force majeure event',  'subject matter hereof', 'confidential information',
                'work product', 'shall deemed', 'disclosing party', 'without limitation', 'indemnified party', 
                'indemnifying party', 'applicable law', 'force majeure', 'trade secret', 'obligation agreement', 
                'intellectual industrial']

addendum_keywords = ['addendum', 'amendment', 'book production', 'production health', 'agreement amendment', 
                     'agreement addendum', 'addendum number', 'addendum executed', 'amendment agreement', 'sow subsequent', 
                     'subsequent addendum', 'addendum made', 'amendment number', 'amendment date', 'amendment entered', 
                     'amendment made', 'amendment executed', 'amendment term', 'amendment effective date', 
                     'inconsistent contradictory term', 'addendum may executed', 'addendum made entered', 'effective date addendum', 
                     'addendum statement work', 'amendment made entered', 'addendum effective date', 
                     'effective date amendment', 'amend agreement', 'agreement amended', 'agreement hereby amended', 
                     'service agreement amendment']

sow_keywords = ['statement work','sow','term sow','sow effective date', 'work sow', 'sow shall', 'sow consultant',
                'sow term', 'service sow', 'sow project', 'defined sow','specified sow','outlined sow','msa sow',
                'addendum sow', 'client sow','sow client', 'sow agreement', 'statement work effective', 
                'agreement statement work']

nda_keywords = ['mutual confidentiality', 'affiliated entity', 'agreement negotiation', 'disclosure hereunder', 'confidentiality confidential', 'protect confidentiality', 'mutual confidentiality agreement', 'disclosure confidential information', 'non disclosure agreement', 'non confidential basis', 'confidential information agent', 'confidentiality non disclosure', 'disclosing party prompt', 'notice intent terminate']

ABSTAIN = -1
#MSA = 1
#ADDENDUM = 0
#SOW = 4
#OTHERS = 3
NDA = 2

def keyword_lookup(x, keywords, label):
    if any(word in x.text.lower() for word in keywords):
        return label
    return ABSTAIN


def make_keyword_lf(keywords, label=NDA):
    return LabelingFunction(
        name=f"keyword_{keywords[0]}",
        f=keyword_lookup,
        resources=dict(keywords=keywords, label=label))

labl_functions = []
for key in nda_keywords:
    labl_functions.append(make_keyword_lf([key]))

@labeling_function()
def others_lookup(x):
    if all(word not in x.text.lower() for word in list(set(msa_keywords + sow_keywords +  nda_keywords + addendum_keywords))):
        return OTHERS
    return ABSTAIN
#labl_functions.append(others_lookup)
print(labl_functions)

applier = PandasLFApplier(lfs=labl_functions)
L_train = applier.apply(df=df_nda)
# Out:
# /home/user/anaconda3/lib/python3.7/site-packages/tqdm/std.py:651: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   from pandas import Panel
# 100%|██████████| 134/134 [00:00<00:00, 3210.48it/s]
# [LabelingFunction keyword_mutual confidentiality, Preprocessors: [], LabelingFunction keyword_affiliated entity, Preprocessors: [], LabelingFunction keyword_agreement negotiation, Preprocessors: [], LabelingFunction keyword_disclosure hereunder, Preprocessors: [], LabelingFunction keyword_confidentiality confidential, Preprocessors: [], LabelingFunction keyword_protect confidentiality, Preprocessors: [], LabelingFunction keyword_mutual confidentiality agreement, Preprocessors: [], LabelingFunction keyword_disclosure confidential information, Preprocessors: [], LabelingFunction keyword_non disclosure agreement, Preprocessors: [], LabelingFunction keyword_non confidential basis, Preprocessors: [], LabelingFunction keyword_confidential information agent, Preprocessors: [], LabelingFunction keyword_confidentiality non disclosure, Preprocessors: [], LabelingFunction keyword_disclosing party prompt, Preprocessors: [], LabelingFunction keyword_notice intent terminate, Preprocessors: []]

# %%
y_nda = df_nda[df_nda.label == 'NDA']['label'].map({'Addendum': 0, 'MSA': 1, 'SOW': 4, 'NDA': 2, 'Others': 3}).values

# %%
from snorkel.labeling import LFAnalysis
LFAnalysis(L=L_train, lfs=labl_functions).lf_summary(y_nda).sort_values(by='Emp. Acc.')
# Out:
#                                               j Polarity  Coverage  Overlaps  \
# keyword_mutual confidentiality                0      [2]  0.604478  0.604478
# keyword_affiliated entity                     1      [2]  0.492537  0.485075
# keyword_agreement negotiation                 2      [2]  0.485075  0.485075
# keyword_disclosure hereunder                  3      [2]  0.664179  0.649254
# keyword_confidentiality confidential          4      [2]  0.477612  0.477612
# keyword_protect confidentiality               5      [2]  0.432836  0.425373
# keyword_mutual confidentiality agreement      6      [2]  0.492537  0.492537
# keyword_disclosure confidential information   7      [2]  0.626866  0.604478
# keyword_non disclosure agreement              8      [2]  0.514925  0.500000
# keyword_non confidential basis                9      [2]  0.537313  0.537313
# keyword_confidential information agent       10      [2]  0.365672  0.365672
# keyword_confidentiality non disclosure       11      [2]  0.567164  0.567164
# keyword_disclosing party prompt              12      [2]  0.567164  0.552239
# keyword_notice intent terminate              13      [2]  0.485075  0.485075
#
#                                              Conflicts  Correct  Incorrect  \
# keyword_mutual confidentiality                     0.0       81          0
# keyword_affiliated entity                          0.0       66          0
# keyword_agreement negotiation                      0.0       65          0
# keyword_disclosure hereunder                       0.0       89          0
# keyword_confidentiality confidential               0.0       64          0
# keyword_protect confidentiality                    0.0       58          0
# keyword_mutual confidentiality agreement           0.0       66          0
# keyword_disclosure confidential information        0.0       84          0
# keyword_non disclosure agreement                   0.0       69          0
# keyword_non confidential basis                     0.0       72          0
# keyword_confidential information agent             0.0       49          0
# keyword_confidentiality non disclosure             0.0       76          0
# keyword_disclosing party prompt                    0.0       76          0
# keyword_notice intent terminate                    0.0       65          0
#
#                                              Emp. Acc.
# keyword_mutual confidentiality                     1.0
# keyword_affiliated entity                          1.0
# keyword_agreement negotiation                      1.0
# keyword_disclosure hereunder                       1.0
# keyword_confidentiality confidential               1.0
# keyword_protect confidentiality                    1.0
# keyword_mutual confidentiality agreement           1.0
# keyword_disclosure confidential information        1.0
# keyword_non disclosure agreement                   1.0
# keyword_non confidential basis                     1.0
# keyword_confidential information agent             1.0
# keyword_confidentiality non disclosure             1.0
# keyword_disclosing party prompt                    1.0
# keyword_notice intent terminate                    1.0
