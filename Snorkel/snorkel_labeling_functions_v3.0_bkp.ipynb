# %%
import os
import re
import pandas as pd
import numpy as np
import tensorflow as tf
# Out:
# /home/inno/innovation/Shyam/venv_shyam/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/inno/innovation/Shyam/venv_shyam/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/inno/innovation/Shyam/venv_shyam/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/inno/innovation/Shyam/venv_shyam/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/inno/innovation/Shyam/venv_shyam/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/inno/innovation/Shyam/venv_shyam/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /home/inno/innovation/Shyam/venv_shyam/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/inno/innovation/Shyam/venv_shyam/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/inno/innovation/Shyam/venv_shyam/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/inno/innovation/Shyam/venv_shyam/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/inno/innovation/Shyam/venv_shyam/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/inno/innovation/Shyam/venv_shyam/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
pd.options.display.max_rows = 4000

# %% [markdown]
# ### Preprocess

# %%
def get_text_start_pos(text):
    pos = 0
    match1 = re.search(r"(addendum|amendment|change request|change order|agreement|sow|statement of work|work order|task order)\s+(\S+\s+){1,30}(by and between|by and among|between|among) (.+?) and (.+?)", text)
    match2 = re.search(r"(addendum|amendment|change request|change order|agreement|sow|statement of work|work order|task order)\s+(\S+\s+){1,30}(effective|dated|entered|executed|made) (.+?) and (.+?)", text)
    match3 = re.search(r"(addendum|amendment|change request|change order|agreement|sow|statement of work|work order|task order)(.+?)(the undersigned)(.+?) and (.+?)", text)
    if match1 and match1.start() < 1000:
        pos = match1.start()
    elif match2 and match2.start() < 1000:
        pos = match2.start()
    elif match3 and match3.start() < 1000:
        pos = match3.start()
    return pos

# %%
def preprocess(text):
    #Preprocess                
    text = text.replace('\n',' ').lower()
    
    #Remove non-alpha characters
    text = re.sub('[^a-zA-Z]', ' ', text)
    text = re.sub(r'\s+', ' ', text)
    pos = get_text_start_pos(text)
    text = text[pos:]
    #Remove articles
    #articles = ('a', 'an', 'the')
    #text = ' '.join([t for t in text.split() if t not in articles])

    return text

# %% [markdown]
# ### Import Labeled Data

# %%
df_labeled = pd.read_csv('../datafiles/labeled_data_new1.csv') #without removing stop words 
#df_labeled = pd.read_csv('labeled_data.csv') #with removing stop words
df_labeled.head()
print(df_labeled.shape)
# Out:
# (1397, 3)

# %%
df_labeled.label.value_counts()
# Out:
# MSA         463
# Addendum    314
# Others      250
# SOW         236
# NDA         134
# Name: label, dtype: int64

# %%
#Split labelled data into test and dev sets
import numpy as np
msk = np.random.rand(len(df_labeled)) < 0.8

df_dev = df_labeled[msk]
df_test = df_labeled[~msk]

# %%
print(df_test.shape, df_dev.shape)
# Out:
# (285, 3) (1112, 3)

# %%
df_dev.label.value_counts()
# Out:
# MSA         363
# Addendum    253
# Others      196
# SOW         190
# NDA         110
# Name: label, dtype: int64

# %%
y_test = df_test.label.map({'Addendum': 0, 'MSA': 1, 'SOW': 4, 'NDA': 2, 'Others': 3})
y_test = np.array(y_test)
np.bincount(y_test)
# Out:
# array([ 61, 100,  24,  54,  46])

# %%
y_dev = df_dev.label.map({'Addendum': 0, 'MSA': 1, 'SOW': 4, 'NDA': 2, 'Others': 3})
y_dev = np.array(y_dev)
np.bincount(y_dev)
# Out:
# array([253, 363, 110, 196, 190])

# %%
df_test.drop('label', axis=1, inplace=True)
df_dev.drop('label', axis=1, inplace=True)
# Out:
# /home/inno/innovation/Shyam/venv_shyam/lib/python3.6/site-packages/pandas/core/frame.py:4102: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %% [markdown]
# ### Import Unlabeled Data

# %%
df_unlabeled = pd.read_csv('../datafiles/unlabeled_data_new1.csv') #without removing stop words
#df_unlabeled = pd.read_csv('unlabeled_data.csv') #with removing stop words
df_unlabeled.shape
# Out:
# (15472, 2)

# %%
df_unlabeled.tail()
# Out:
#                       filename  \
# 15467  D16492.pdf.out.html.txt
# 15468  D19966.pdf.out.html.txt
# 15469  D26253.pdf.out.html.txt
# 15470  D37991.pdf.out.html.txt
# 15471  D01957.pdf.out.html.txt
#
#                                                     text
# 15467   ert oep ik ie scope of work corporate mobilit...
# 15468   w f bof hl lai b statement of work for gss in...
# 15469  statement of work wolters kluwer united states...
# 15470  statement of work including all exhibits attac...
# 15471   statement of work no sow services definitions...

# %%
#Split unlabelled data into train and valid sets
import numpy as np
msk = np.random.rand(len(df_unlabeled)) < 0.02

df_train = df_unlabeled[~msk]
df_valid = df_unlabeled[msk]

# %%
print(df_train.shape, df_valid.shape)
# Out:
# (15164, 2) (308, 2)

# %% [markdown]
# ### Labeling Functions

# %%
from snorkel.labeling import labeling_function
from snorkel.labeling import LabelingFunction
from snorkel.labeling import PandasLFApplier

ABSTAIN = -1
MSA = 1
SOW = 4
ADDENDUM = 0
NDA = 2
OTHERS = 3

labl_functions = []

def keyword_lookup(x, keywords, label):
    if any(word in x.text.lower() for word in keywords):
        return label
    return ABSTAIN

#===============MSA=======================
@labeling_function()
def msa_regex_lookup(x):    
    nonmsa_keywords = ['sow', 'statement of work', 'addendum', 'amendment', 'confidentiality agreement', 'disclosure agreement']
    match1 = re.search(r"(agreement agreement|master agreement|master services agreement|this agreement)\s+(\S+\s+){1,30}(by and between|by and among|between|among)(.+?) and (.+?)", x.text)
    match2 = re.search(r"(agreement agreement|master agreement|master services agreement|this agreement)\s+(\S+\s+){1,30}(effective)(.+?) and (.+?)", x.text)
    match3 = re.search(r"(agreement agreement|master agreement|master services agreement|this agreement)\s+(\S+\s+){1,30}(the undersigned)(.+?) and (.+?)", x.text)
        
    if (match1 and not(any(key in x.text[:match1.end()] for key in nonmsa_keywords))) \
        or (match2 and not(any(key in x.text[:match2.end()] for key in nonmsa_keywords))) \
        or (match3 and not(any(key in x.text[:match3.end()] for key in nonmsa_keywords))):
        return MSA
    return ABSTAIN

labl_functions.append(msa_regex_lookup)

msa_keywords = ['indemnified party', 'indemnifying party', 'force majeure', 'intellectual industrial', 
                'wk service provider', 'intellectual industrial property', 'industrial property right', 
                'privacy restricted data', 'prior written notice', 'force majeure event', 'subject matter hereof']

def make_keyword_lf_msa(keywords, label=MSA):
    return LabelingFunction(
        name=f"keyword_{keywords[0]}",
        f=keyword_lookup,
        resources=dict(keywords=keywords, label=label))

for key in msa_keywords:
    labl_functions.append(make_keyword_lf_msa([key]))
    
 
#===============ADDENDUM===================
@labeling_function()
def addendum_regex_lookup(x):
    match1 = re.search(r"(addendum|amendment|change request|change order)\s+(\S+\s+){1,30}(by and between|by and among|between) (.+?) and (.+?)", x.text)
    match2 = re.search(r"(addendum|amendment)\s+(\S+\s+){1,30}(schedule a|effective) (.+?) and (.+?)", x.text)
    match3 = re.search(r"(addendum|amendment) (.+?) (the undersigned) (.+?) and (.+?)", x.text)
    
    if (match1 and match1.start() < 1000) or (match2 and match2.start() < 1000) or (match3 and match3.start() < 1000):
        return ADDENDUM
    return ABSTAIN

labl_functions.append(addendum_regex_lookup)

addendum_keywords = ['rom work', 'addendum number', 'addendum part', 'amendment part',
                     'term addendum', 'term amendment', 'addendum made entered',
                     'addendum entered', 'duration addendum', 
                     'purpose addendum', 
                     'addendum executed', 'subsequent addendum', 'amendment number', 
                     'amendment date', 'amendment entered', 'amendment made', 'amendment executed', 
                     'amendment effective date', 
                     'addendum may executed', 'effective date addendum', 
                     'amendment made entered', 
                     'agreement hereby amended', 'service agreement amendment']

def make_keyword_lf_addendum(keywords, label=ADDENDUM):
    return LabelingFunction(
        name=f"keyword_{keywords[0]}",
        f=keyword_lookup,
        resources=dict(keywords=keywords, label=label),
    )

for key in addendum_keywords:
    labl_functions.append(make_keyword_lf_addendum([key]))

#===============SOW===================
@labeling_function()
def sow_regex_lookup(x):    
    nonsow_keywords = ['addendum','amendment']
    match1 = re.search(r"(sow|statement of work|work order|task order)\s+(\S+\s+){1,30}(by and between|by and among|executed by|between|entered into)(.+?) and (.+?)", x.text)
    match2 = re.search(r"(sow|statement of work|work order|task order)\s+(\S+\s+){1,30}(effective) (.+?) and (.+?)", x.text)
    match3 = re.search(r"(sow|statement of work|work order|task order)\s+(\S+\s+){1,30}(the undersigned) (.+?) and (.+?)", x.text)
       
    if (match1 and match1.start() < 1000 and not(any(key in x.text[:match1.end()] for key in nonsow_keywords)) \
        or (match2 and match2.start() < 1000 and not(any(key not in x.text[:match2.end()] for key in nonsow_keywords))) \
        or match3 and match3.start() < 1000 and not(any(key not in x.text[:match3.end()] for key in nonsow_keywords))):
        return SOW
    return ABSTAIN

labl_functions.append(sow_regex_lookup)

sow_keywords = ['sow effective date', 'work sow', 'sow shall', 'sow term', 'service sow', 'defined sow', 
                'specified sow', 'outlined sow', 'addendum sow', 'client sow', 'sow agreement', 
                'statement work effective', 'sow end date', 'sow duration']

def make_keyword_lf_sow(keywords, label=SOW):
    return LabelingFunction(
        name=f"keyword_{keywords[0]}",
        f=keyword_lookup,
        resources=dict(keywords=keywords, label=label),
    )

for key in sow_keywords:
    labl_functions.append(make_keyword_lf_sow([key]))

#===============NDA===================
@labeling_function()
def nda_regex_lookup(x):
    nda_keywords = ['mutual confidentiality', 'confidentiality agreement', 'disclosure agreement']
    match1 = re.search(r"(disclosure agreement|confidentiality agreement)\s+(\S+\s+){1,30}(by and between|by and among|between|among)(.+?) and (.+?)", x.text)
    
    if match1 and match1.start() < 1000 and any(key in x.text for key in nda_keywords):
        return NDA
    return ABSTAIN

labl_functions.append(nda_regex_lookup)

nda_keywords = ['mutual confidentiality', 'affiliated entity', 'agreement negotiation', 'disclosure hereunder', 
                'mutual confidentiality agreement', 'non confidential basis', 'confidential information agent', 
                'confidentiality non disclosure', 'party certain confidential information',
                'party desire disclose party', 'party wish protect','party furnish']

def make_keyword_lf_nda(keywords, label=NDA):
    return LabelingFunction(
        name=f"keyword_{keywords[0]}",
        f=keyword_lookup,
        resources=dict(keywords=keywords, label=label),
    )

for key in nda_keywords:
    labl_functions.append(make_keyword_lf_nda([key]))
    

#===============OTHERS===================
@labeling_function()
def others_lookup(x):
    msa = msa_regex_lookup(x)
    sow = sow_regex_lookup(x)
    addendum = addendum_regex_lookup(x)
    nda = nda_regex_lookup(x)
    
    if msa == ABSTAIN and sow == ABSTAIN and addendum == ABSTAIN and nda == ABSTAIN:
        return OTHERS
    return ABSTAIN    
    
#labl_functions.append(others_lookup)

other_keywords = ['sir madam letter', 'letter inform', 'engagement letter', 'service order form',
                  'change request form', 'signature form', 'agreement service order', 'service component order', 
                  'term service order', 'component order']

def make_keyword_lf_others(keywords, label=OTHERS):
    return LabelingFunction(
        name=f"keyword_{keywords[0]}",
        f=keyword_lookup,
        resources=dict(keywords=keywords, label=label),
    )

for key in other_keywords:
    labl_functions.append(make_keyword_lf_others([key]))
    
@labeling_function()
def others_keyword_lookup(x):
    if all(word not in x.text for word in list(set(msa_keywords + sow_keywords + nda_keywords + addendum_keywords))):
        return OTHERS
    return ABSTAIN

#labl_functions.append(others_keyword_lookup)

print(len(labl_functions))
# Out:
# 74

# %% [markdown]
# ### Apply Label Functions to Corpus

# %%
#Apply the label functions to the train and valid sets
applier = PandasLFApplier(lfs=labl_functions)
L_train = applier.apply(df=df_train)
L_dev = applier.apply(df=df_dev)
L_valid = applier.apply(df=df_valid)
L_unlabelled = applier.apply(df=df_unlabeled)
# Out:
# 100%|██████████| 15164/15164 [00:43<00:00, 352.45it/s]
# 100%|██████████| 1112/1112 [00:04<00:00, 259.91it/s]
# 100%|██████████| 308/308 [00:00<00:00, 406.27it/s]
# 100%|██████████| 15472/15472 [00:44<00:00, 351.00it/s]

# %%
#Check the coverage of label functions on train set

from snorkel.labeling import LFAnalysis
LFAnalysis(L=L_train, lfs=labl_functions).lf_summary().sort_values(by='Coverage')
# Out:
#                                                  j Polarity  Coverage  \
# keyword_agreement hereby amended                34       []  0.000000
# keyword_addendum made entered                   19       []  0.000000
# keyword_duration addendum                       21       []  0.000000
# keyword_addendum may executed                   31       []  0.000000
# keyword_amendment made entered                  33       []  0.000000
# keyword_specified sow                           43       []  0.000000
# keyword_addendum sow                            45       []  0.000000
# keyword_outlined sow                            44       []  0.000000
# keyword_party desire disclose party             61       []  0.000000
# keyword_party wish protect                      62       []  0.000000
# keyword_sir madam letter                        64       []  0.000000
# keyword_statement work effective                48       []  0.000000
# keyword_term amendment                          18       []  0.000000
# keyword_intellectual industrial property         6      [1]  0.000066
# keyword_term addendum                           17      [0]  0.000066
# keyword_defined sow                             42      [4]  0.000066
# keyword_intellectual industrial                  4      [1]  0.000066
# keyword_purpose addendum                        22      [0]  0.000066
# keyword_letter inform                           65      [3]  0.000066
# keyword_component order                         73      [3]  0.000132
# keyword_service component order                 71      [3]  0.000132
# keyword_addendum part                           15      [0]  0.000198
# keyword_service sow                             41      [4]  0.000198
# keyword_term service order                      72      [3]  0.000198
# keyword_service agreement amendment             35      [0]  0.000264
# keyword_amendment entered                       27      [0]  0.000330
# keyword_amendment part                          16      [0]  0.000396
# keyword_effective date addendum                 32      [0]  0.000396
# keyword_addendum entered                        20      [0]  0.000396
# keyword_agreement negotiation                   54      [2]  0.000462
# keyword_sow agreement                           47      [4]  0.000462
# keyword_agreement service order                 70      [3]  0.000857
# keyword_amendment made                          28      [0]  0.001121
# keyword_confidential information agent          58      [2]  0.001319
# keyword_wk service provider                      5      [1]  0.001385
# keyword_sow duration                            50      [4]  0.001517
# keyword_addendum executed                       23      [0]  0.001517
# keyword_amendment executed                      29      [0]  0.001781
# keyword_signature form                          69      [3]  0.001978
# keyword_sow end date                            49      [4]  0.003034
# keyword_rom work                                13      [0]  0.003099
# keyword_amendment date                          26      [0]  0.003759
# keyword_service order form                      67      [3]  0.005144
# keyword_engagement letter                       66      [3]  0.006001
# keyword_amendment number                        25      [0]  0.006133
# keyword_addendum number                         14      [0]  0.006661
# keyword_change request form                     68      [3]  0.007716
# keyword_party certain confidential information  60      [2]  0.007716
# keyword_party furnish                           63      [2]  0.008111
# keyword_sow term                                40      [4]  0.009430
# keyword_confidentiality non disclosure          59      [2]  0.009496
# keyword_client sow                              46      [4]  0.010419
# keyword_affiliated entity                       53      [2]  0.010749
# keyword_amendment effective date                30      [0]  0.012991
# nda_regex_lookup                                51      [2]  0.018795
# keyword_sow effective date                      37      [4]  0.021564
# keyword_privacy restricted data                  8      [1]  0.024004
# keyword_industrial property right                7      [1]  0.036600
# keyword_mutual confidentiality agreement        56      [2]  0.039765
# keyword_indemnified party                        1      [1]  0.041150
# keyword_mutual confidentiality                  52      [2]  0.042337
# keyword_indemnifying party                       2      [1]  0.042931
# keyword_subsequent addendum                     24      [0]  0.046030
# keyword_non confidential basis                  57      [2]  0.049657
# keyword_force majeure event                     10      [1]  0.054405
# keyword_disclosure hereunder                    55      [2]  0.057109
# keyword_sow shall                               39      [4]  0.060406
# keyword_work sow                                38      [4]  0.068122
# keyword_force majeure                            3      [1]  0.092522
# keyword_subject matter hereof                   11      [1]  0.103601
# sow_regex_lookup                                36      [4]  0.104194
# keyword_prior written notice                     9      [1]  0.110129
# addendum_regex_lookup                           12      [0]  0.173107
# msa_regex_lookup                                 0      [1]  0.210960
#
#                                                 Overlaps  Conflicts
# keyword_agreement hereby amended                0.000000   0.000000
# keyword_addendum made entered                   0.000000   0.000000
# keyword_duration addendum                       0.000000   0.000000
# keyword_addendum may executed                   0.000000   0.000000
# keyword_amendment made entered                  0.000000   0.000000
# keyword_specified sow                           0.000000   0.000000
# keyword_addendum sow                            0.000000   0.000000
# keyword_outlined sow                            0.000000   0.000000
# keyword_party desire disclose party             0.000000   0.000000
# keyword_party wish protect                      0.000000   0.000000
# keyword_sir madam letter                        0.000000   0.000000
# keyword_statement work effective                0.000000   0.000000
# keyword_term amendment                          0.000000   0.000000
# keyword_intellectual industrial property        0.000066   0.000066
# keyword_term addendum                           0.000066   0.000000
# keyword_defined sow                             0.000066   0.000066
# keyword_intellectual industrial                 0.000066   0.000066
# keyword_purpose addendum                        0.000066   0.000000
# keyword_letter inform                           0.000066   0.000066
# keyword_component order                         0.000132   0.000132
# keyword_service component order                 0.000132   0.000132
# keyword_addendum part                           0.000198   0.000066
# keyword_service sow                             0.000198   0.000132
# keyword_term service order                      0.000198   0.000198
# keyword_service agreement amendment             0.000264   0.000000
# keyword_amendment entered                       0.000330   0.000264
# keyword_amendment part                          0.000396   0.000066
# keyword_effective date addendum                 0.000396   0.000000
# keyword_addendum entered                        0.000396   0.000132
# keyword_agreement negotiation                   0.000462   0.000396
# keyword_sow agreement                           0.000462   0.000066
# keyword_agreement service order                 0.000857   0.000857
# keyword_amendment made                          0.001121   0.000462
# keyword_confidential information agent          0.001319   0.001121
# keyword_wk service provider                     0.001253   0.000066
# keyword_sow duration                            0.001451   0.000791
# keyword_addendum executed                       0.001517   0.001319
# keyword_amendment executed                      0.001649   0.000857
# keyword_signature form                          0.000857   0.000857
# keyword_sow end date                            0.003034   0.001319
# keyword_rom work                                0.002440   0.002374
# keyword_amendment date                          0.003429   0.000857
# keyword_service order form                      0.002242   0.002242
# keyword_engagement letter                       0.002836   0.002836
# keyword_amendment number                        0.006001   0.001451
# keyword_addendum number                         0.006595   0.000132
# keyword_change request form                     0.006001   0.006001
# keyword_party certain confidential information  0.007716   0.001715
# keyword_party furnish                           0.008111   0.003297
# keyword_sow term                                0.009101   0.003825
# keyword_confidentiality non disclosure          0.009496   0.002242
# keyword_client sow                              0.010419   0.000791
# keyword_affiliated entity                       0.010288   0.003034
# keyword_amendment effective date                0.012596   0.003759
# nda_regex_lookup                                0.015168   0.005803
# keyword_sow effective date                      0.021037   0.005342
# keyword_privacy restricted data                 0.023872   0.006858
# keyword_industrial property right               0.034951   0.008309
# keyword_mutual confidentiality agreement        0.039765   0.028489
# keyword_indemnified party                       0.038512   0.011343
# keyword_mutual confidentiality                  0.041744   0.029873
# keyword_indemnifying party                      0.042601   0.011606
# keyword_subsequent addendum                     0.045898   0.002110
# keyword_non confidential basis                  0.049195   0.035677
# keyword_force majeure event                     0.054405   0.011870
# keyword_disclosure hereunder                    0.056779   0.044513
# keyword_sow shall                               0.056252   0.017410
# keyword_work sow                                0.063176   0.022619
# keyword_force majeure                           0.086719   0.022685
# keyword_subject matter hereof                   0.097929   0.026378
# sow_regex_lookup                                0.082630   0.029544
# keyword_prior written notice                    0.099710   0.030401
# addendum_regex_lookup                           0.097731   0.031258
# msa_regex_lookup                                0.151873   0.063901

# %%
#Check the Coverage and Accuracy of label functions on dev set

LFAnalysis(L=L_dev, lfs=labl_functions).lf_summary(y_dev).sort_values(by='Emp. Acc.')
# Out:
#                                                  j Polarity  Coverage  \
# keyword_component order                         73       []  0.000000
# keyword_addendum entered                        20       []  0.000000
# keyword_duration addendum                       21       []  0.000000
# keyword_purpose addendum                        22       []  0.000000
# keyword_addendum sow                            45       []  0.000000
# keyword_outlined sow                            44       []  0.000000
# keyword_specified sow                           43       []  0.000000
# keyword_addendum made entered                   19       []  0.000000
# keyword_defined sow                             42       []  0.000000
# keyword_amendment made                          28       []  0.000000
# keyword_amendment executed                      29       []  0.000000
# keyword_addendum may executed                   31       []  0.000000
# keyword_effective date addendum                 32       []  0.000000
# keyword_amendment made entered                  33       []  0.000000
# keyword_agreement hereby amended                34       []  0.000000
# keyword_service sow                             41       []  0.000000
# keyword_service agreement amendment             35       []  0.000000
# keyword_term amendment                          18       []  0.000000
# keyword_amendment part                          16       []  0.000000
# keyword_service component order                 71       []  0.000000
# keyword_agreement service order                 70       []  0.000000
# keyword_intellectual industrial                  4       []  0.000000
# keyword_intellectual industrial property         6       []  0.000000
# keyword_term addendum                           17       []  0.000000
# keyword_letter inform                           65       []  0.000000
# keyword_term service order                      72       []  0.000000
# keyword_party wish protect                      62       []  0.000000
# keyword_party desire disclose party             61       []  0.000000
# keyword_agreement negotiation                   54       []  0.000000
# keyword_statement work effective                48       []  0.000000
# keyword_sir madam letter                        64       []  0.000000
# keyword_change request form                     68      [3]  0.009892
# keyword_rom work                                13      [0]  0.006295
# keyword_sow agreement                           47      [4]  0.003597
# keyword_engagement letter                       66      [3]  0.001799
# keyword_service order form                      67      [3]  0.004496
# keyword_sow term                                40      [4]  0.012590
# msa_regex_lookup                                 0      [1]  0.351619
# keyword_amendment date                          26      [0]  0.003597
# keyword_prior written notice                     9      [1]  0.181655
# keyword_work sow                                38      [4]  0.093525
# keyword_sow shall                               39      [4]  0.090827
# keyword_force majeure                            3      [1]  0.150180
# keyword_subject matter hereof                   11      [1]  0.161871
# sow_regex_lookup                                36      [4]  0.153777
# keyword_non confidential basis                  57      [2]  0.058453
# keyword_amendment effective date                30      [0]  0.017986
# keyword_privacy restricted data                  8      [1]  0.034173
# keyword_sow effective date                      37      [4]  0.047662
# keyword_force majeure event                     10      [1]  0.097122
# keyword_industrial property right                7      [1]  0.066547
# keyword_disclosure hereunder                    55      [2]  0.067446
# keyword_indemnified party                        1      [1]  0.068345
# keyword_indemnifying party                       2      [1]  0.070144
# keyword_subsequent addendum                     24      [0]  0.025180
# addendum_regex_lookup                           12      [0]  0.214029
# keyword_mutual confidentiality                  52      [2]  0.048561
# keyword_signature form                          69      [3]  0.001799
# keyword_wk service provider                      5      [1]  0.005396
# keyword_amendment entered                       27      [0]  0.000899
# keyword_party furnish                           63      [2]  0.008993
# keyword_addendum executed                       23      [0]  0.000899
# keyword_party certain confidential information  60      [2]  0.010791
# keyword_confidential information agent          58      [2]  0.000899
# keyword_mutual confidentiality agreement        56      [2]  0.044964
# keyword_affiliated entity                       53      [2]  0.013489
# nda_regex_lookup                                51      [2]  0.016187
# keyword_sow duration                            50      [4]  0.002698
# keyword_sow end date                            49      [4]  0.004496
# keyword_addendum number                         14      [0]  0.029676
# keyword_addendum part                           15      [0]  0.000899
# keyword_client sow                              46      [4]  0.016187
# keyword_amendment number                        25      [0]  0.011691
# keyword_confidentiality non disclosure          59      [2]  0.013489
#
#                                                 Overlaps  Conflicts  Correct  \
# keyword_component order                         0.000000   0.000000        0
# keyword_addendum entered                        0.000000   0.000000        0
# keyword_duration addendum                       0.000000   0.000000        0
# keyword_purpose addendum                        0.000000   0.000000        0
# keyword_addendum sow                            0.000000   0.000000        0
# keyword_outlined sow                            0.000000   0.000000        0
# keyword_specified sow                           0.000000   0.000000        0
# keyword_addendum made entered                   0.000000   0.000000        0
# keyword_defined sow                             0.000000   0.000000        0
# keyword_confidentiality non disclosure          0.013489   0.000899       15
#
#                                                 Incorrect  Emp. Acc.
# keyword_component order                                 0   0.000000
# keyword_addendum entered                                0   0.000000
# keyword_duration addendum                               0   0.000000
# keyword_purpose addendum                                0   0.000000
# keyword_addendum sow                                    0   0.000000
# keyword_outlined sow                                    0   0.000000
# keyword_specified sow                                   0   0.000000
# keyword_addendum made entered                           0   0.000000
# keyword_defined sow                                     0   0.000000
# keyword_amendment made                                  0   0.000000
# keyword_amendment executed                              0   0.000000
# keyword_addendum may executed                           0   0.000000
# keyword_effective date addendum                         0   0.000000
# keyword_amendment made entered                          0   0.000000
# keyword_agreement hereby amended                        0   0.000000
# keyword_service sow                                     0   0.000000
# keyword_service agreement amendment                     0   0.000000
# keyword_term amendment                                  0   0.000000
# keyword_amendment part                                  0   0.000000
# keyword_service component order                         0   0.000000
# keyword_agreement service order                         0   0.000000
# keyword_intellectual industrial                         0   0.000000
# keyword_intellectual industrial property                0   0.000000
# keyword_term addendum                                   0   0.000000
# keyword_letter inform                                   0   0.000000
# keyword_term service order                              0   0.000000
# keyword_party wish protect                              0   0.000000
# keyword_party desire disclose party                     0   0.000000
# keyword_agreement negotiation                           0   0.000000
# keyword_statement work effective                        0   0.000000
# keyword_sir madam letter                                0   0.000000
# keyword_change request form                            10   0.090909
# keyword_rom work                                        6   0.142857
# keyword_sow agreement                                   2   0.500000
# keyword_engagement letter                               1   0.500000
# keyword_service order form                              2   0.600000
# keyword_sow term                                        4   0.714286
# msa_regex_lookup                                      107   0.726343
# keyword_amendment date                                  1   0.750000
# keyword_prior written notice                           35   0.826733
# keyword_work sow                                       18   0.826923
# keyword_sow shall                                      15   0.851485
# keyword_force majeure                                  24   0.856287
# keyword_subject matter hereof                          23   0.872222
# sow_regex_lookup                                       19   0.888889
# keyword_non confidential basis                          7   0.892308
# keyword_amendment effective date                        2   0.900000
# keyword_privacy restricted data                         3   0.921053
# keyword_sow effective date                              3   0.943396
# keyword_force majeure event                             6   0.944444
# keyword_industrial property right                       4   0.945946
# keyword_disclosure hereunder                            4   0.946667
# keyword_indemnified party                               3   0.960526
# keyword_indemnifying party                              3   0.961538
# keyword_subsequent addendum                             1   0.964286
# addendum_regex_lookup                                   6   0.974790
# keyword_mutual confidentiality                          1   0.981481
# keyword_signature form                                  0   1.000000
# keyword_wk service provider                             0   1.000000
# keyword_amendment entered                               0   1.000000
# keyword_party furnish                                   0   1.000000
# keyword_addendum executed                               0   1.000000
# keyword_party certain confidential information          0   1.000000
# keyword_confidential information agent                  0   1.000000
# keyword_mutual confidentiality agreement                0   1.000000
# keyword_affiliated entity                               0   1.000000
# nda_regex_lookup                                        0   1.000000
# keyword_sow duration                                    0   1.000000
# keyword_sow end date                                    0   1.000000
# keyword_addendum number                                 0   1.000000
# keyword_addendum part                                   0   1.000000
# keyword_client sow                                      0   1.000000
# keyword_amendment number                                0   1.000000
# keyword_confidentiality non disclosure                  0   1.000000

# %% [markdown]
# ### Label Model

# %%
from snorkel.labeling import LabelModel
label_model = LabelModel(cardinality=5, verbose=True)
#label_model.fit(L_train, n_epochs=500, lr=0.001, log_freq=50, seed=123)
label_model.fit(L_unlabelled, n_epochs=500, lr=0.001, log_freq=50, seed=123) #this is for gridsearchCV where train and valid split not required

# %%
label_model_acc = label_model.score(L=L_dev, Y=y_dev)["accuracy"]
print(f"{'Label Model Accuracy:':<25} {label_model_acc * 100:.1f}%")
# Out:
# W1122 20:14:20.051949 139883909470016 label_model.py:501] Metrics calculated over data points with non-abstain labels only
# Label Model Accuracy:     85.8%

# %%
probs_train = label_model.predict_proba(L_train)
probs_train
# Out:
# array([[2.00000000e-01, 2.00000000e-01, 2.00000000e-01, 2.00000000e-01,
#         2.00000000e-01],
#        [5.70167626e-02, 6.66162159e-01, 1.31370499e-01, 7.77928138e-02,
#         6.76577652e-02],
#        [2.00000000e-01, 2.00000000e-01, 2.00000000e-01, 2.00000000e-01,
#         2.00000000e-01],
#        ...,
#        [4.12828122e-17, 9.99999994e-01, 1.02300347e-18, 8.91102701e-14,
#         5.57330811e-09],
#        [1.43905562e-02, 1.32814383e-02, 7.81295201e-03, 1.08649834e-02,
#         9.53650070e-01],
#        [9.01627765e-03, 1.79591228e-02, 4.73964305e-03, 6.88588797e-03,
#         9.61399069e-01]])

# %%
probs_valid = label_model.predict_proba(L_valid)
probs_valid
# Out:
# array([[4.03753288e-05, 5.59768801e-03, 9.93979113e-01, 2.94126975e-04,
#         8.86966786e-05],
#        [2.00000000e-01, 2.00000000e-01, 2.00000000e-01, 2.00000000e-01,
#         2.00000000e-01],
#        [7.61536245e-04, 8.40472678e-02, 9.09991800e-01, 3.81547115e-03,
#         1.38392484e-03],
#        ...,
#        [9.58499051e-01, 8.16754134e-04, 1.09649684e-02, 1.43933202e-02,
#         1.53259061e-02],
#        [1.11509370e-04, 6.22984135e-06, 3.79053377e-05, 7.72716881e-05,
#         9.99767084e-01],
#        [2.00000000e-01, 2.00000000e-01, 2.00000000e-01, 2.00000000e-01,
#         2.00000000e-01]])

# %%
#this is for gridsearchCV where train and valid split not required
probs_full_train = label_model.predict_proba(L_unlabelled)
probs_full_train
# Out:
# array([[2.00000000e-01, 2.00000000e-01, 2.00000000e-01, 2.00000000e-01,
#         2.00000000e-01],
#        [5.70167626e-02, 6.66162159e-01, 1.31370499e-01, 7.77928138e-02,
#         6.76577652e-02],
#        [2.00000000e-01, 2.00000000e-01, 2.00000000e-01, 2.00000000e-01,
#         2.00000000e-01],
#        ...,
#        [4.12828122e-17, 9.99999994e-01, 1.02300347e-18, 8.91102701e-14,
#         5.57330811e-09],
#        [1.43905562e-02, 1.32814383e-02, 7.81295201e-03, 1.08649834e-02,
#         9.53650070e-01],
#        [9.01627765e-03, 1.79591228e-02, 4.73964305e-03, 6.88588797e-03,
#         9.61399069e-01]])

# %% [markdown]
# ### Filter unlaabeled data if any

# %%
from snorkel.labeling import filter_unlabeled_dataframe

"""df_train_filtered, probs_train_filtered = filter_unlabeled_dataframe(
    X=df_train, y=probs_train, L=L_train
)"""

#this is for gridsearchCV where train and valid split not required
df_train_filtered, probs_train_filtered = filter_unlabeled_dataframe(
    X=df_unlabeled, y=probs_full_train, L=L_unlabelled
)

# %%
print(df_train_filtered.shape, probs_train_filtered.shape)
# Out:
# (9027, 2) (9027, 5)

# %%
df_train_filtered = df_train_filtered.text.tolist()
y_train = probs_train_filtered
#df_valid = df_valid.text.tolist()
#y_valid = probs_valid

# %% [markdown]
# ### Training

# %%
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences

max_features = 150 # cut texts after this number of words

# prepare tokenizer
t = Tokenizer(num_words=max_features)
t.fit_on_texts(df_train_filtered)
#t.fit_on_texts(df_valid)
post_seq_train = t.texts_to_sequences(df_train_filtered)
#post_seq_valid = t.texts_to_sequences(df_valid)
X_train = pad_sequences(post_seq_train, maxlen=max_features, padding='post')
#X_valid = pad_sequences(post_seq_valid, maxlen=max_features, padding='post')

# %%
#print(X_train.shape, y_train.shape, X_valid.shape, y_valid.shape)
print(X_train.shape, y_train.shape)
# Out:
# (9027, 150) (9027, 5)

# %%
word_index = t.word_index
len(word_index)
# Out:
# 285742

# %%
#Import Embeddings and create embedding dict
embeddings_index = {}
f = open('../w2v_embedding/cms_word2vec_embedding_300.txt')
for line in f:
    values = line.split()
    word = values[0]
    coefs = np.asarray(values[1:], dtype='float32')
    embeddings_index[word] = coefs
f.close()

# %%
from keras.layers import Embedding
from keras.initializers import Constant

#Create embedding layer
EMBEDDING_DIM = 300
num_words = len(word_index) + 1
embedding_matrix = np.zeros((num_words, EMBEDDING_DIM))
for word, i in word_index.items():
    embedding_vector = embeddings_index.get(word)
    if embedding_vector is not None:
        # words not found in embedding index will be all-zeros.
        embedding_matrix[i] = embedding_vector

# load pre-trained word embeddings into an Embedding layer
# note that we set trainable = False so as to keep the embeddings fixed
embedding_layer = Embedding(num_words,
                            EMBEDDING_DIM,
                            embeddings_initializer=Constant(embedding_matrix),
                            input_length=max_features,
                            trainable=False)
# Out:
# W1122 20:17:07.695820 139883909470016 deprecation_wrapper.py:119] From /home/inno/innovation/Shyam/venv_shyam/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.

# %% [markdown]
# from sklearn.feature_extraction.text import CountVectorizer
#
# vectorizer = CountVectorizer(ngram_range=(1, 3), max_features=100)
# X_train = vectorizer.fit_transform(df_train_filtered)
#
# X_dev = vectorizer.transform(df_dev.text.tolist())
# X_valid = vectorizer.transform(df_valid)
# X_test = vectorizer.transform(df_test.text.tolist())

# %%
from keras.models import Sequential, Model
from keras.layers import Input, Dense, Dropout, Embedding, LSTM, Bidirectional
from utils import get_keras_early_stopping

batch_size = 32

inputs = Input(shape=(max_features,), dtype='int32')
embed = embedding_layer(inputs)
               
#model = Sequential()
#model.add(Embedding(max_features, 128, input_length=48)(embed))
#model.add(Bidirectional(LSTM(64)))
#model.add(Dropout(0.5))
#model.add(Dense(5, activation='softmax'))

x = Bidirectional(LSTM(64))(embed)
x = Dropout(0.5)(x)
x = Dense(5, activation='softmax')(x)
model = Model(inputs = inputs, outputs = x)

# %%
from keras.optimizers import Adam
lr = 0.01
epochs = 10
#decay=lr/epochs
adam = Adam(lr=lr)

model.compile(adam, 'categorical_crossentropy', metrics=['accuracy'])

# %%
model.fit(X_train, y_train,
          batch_size=batch_size,
          epochs=epochs,
          validation_data=[X_valid, y_valid],
          callbacks=[get_keras_early_stopping()])
# Out:
# Train on 8871 samples, validate on 288 samples
# Epoch 1/10
# 8871/8871 [==============================] - 22s 2ms/step - loss: 1.0649 - acc: 0.6703 - val_loss: 1.4868 - val_acc: 0.6944
# Epoch 2/10
# 8871/8871 [==============================] - 20s 2ms/step - loss: 1.0030 - acc: 0.7114 - val_loss: 1.4556 - val_acc: 0.6424
# Epoch 3/10
# 8871/8871 [==============================] - 20s 2ms/step - loss: 0.9785 - acc: 0.7292 - val_loss: 1.4421 - val_acc: 0.6528
# Epoch 4/10
# 8871/8871 [==============================] - 20s 2ms/step - loss: 0.9691 - acc: 0.7350 - val_loss: 1.4592 - val_acc: 0.6875
# Epoch 5/10
# 8871/8871 [==============================] - 20s 2ms/step - loss: 0.9794 - acc: 0.7307 - val_loss: 1.4639 - val_acc: 0.6840
# Epoch 6/10
# 8871/8871 [==============================] - 20s 2ms/step - loss: 0.9825 - acc: 0.7237 - val_loss: 1.4211 - val_acc: 0.6944
# Epoch 7/10
# 8871/8871 [==============================] - 20s 2ms/step - loss: 0.9756 - acc: 0.7295 - val_loss: 1.4237 - val_acc: 0.5868
# Epoch 8/10
# 8871/8871 [==============================] - 20s 2ms/step - loss: 0.9749 - acc: 0.7264 - val_loss: 1.4345 - val_acc: 0.6389
# Epoch 9/10
# 8871/8871 [==============================] - 20s 2ms/step - loss: 0.9850 - acc: 0.7277 - val_loss: 1.4177 - val_acc: 0.6771
# Epoch 10/10
# 8871/8871 [==============================] - 20s 2ms/step - loss: 0.9728 - acc: 0.7355 - val_loss: 1.4247 - val_acc: 0.6632

# %%
from keras.models import Sequential, Model
from keras.layers import Input, Dense, Dropout, Embedding, LSTM, Bidirectional
from utils import get_keras_early_stopping
from keras.optimizers import Adam

def create_model(lr=0.001):
    # create model
    model = Model()
    inputs = Input(shape=(max_features,), dtype='int32')
    embed = embedding_layer(inputs)
    x = Bidirectional(LSTM(64))(embed)
    x = Dropout(0.5)(x)
    x = Dense(5, activation='softmax')(x)
    model = Model(inputs = inputs, outputs = x)
    
    adam = Adam(lr=lr)
    
    # Compile model
    model.compile(adam, 'categorical_crossentropy', metrics=['accuracy'])
    return model

# %%
from keras.wrappers.scikit_learn import KerasClassifier
model = KerasClassifier(build_fn=create_model, batch_size=32, epochs=15, verbose=0)

# %%
from sklearn.model_selection import GridSearchCV

# define the grid search parameters
#batch_size = [10, 20, 40, 60]
#epochs = [10, 25, 50]
lr = [0.001, 0.01, 0.1]
param_grid = dict(lr=lr)
grid = GridSearchCV(estimator=model, param_grid=param_grid, n_jobs=1, cv=5,  verbose=10)
grid_result = grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 3 candidates, totalling 15 fits
# [CV] lr=0.001 ........................................................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# W1122 20:21:36.819225 139883909470016 deprecation_wrapper.py:119] From /home/inno/innovation/Shyam/venv_shyam/lib/python3.6/site-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# W1122 20:21:36.823359 139883909470016 deprecation_wrapper.py:119] From /home/inno/innovation/Shyam/venv_shyam/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:3576: The name tf.log is deprecated. Please use tf.math.log instead.
#
# W1122 20:21:36.894008 139883909470016 deprecation.py:323] From /home/inno/innovation/Shyam/venv_shyam/lib/python3.6/site-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-58-89dc9198a69d> in <module>
#       7 param_grid = dict(lr=lr)
#       8 grid = GridSearchCV(estimator=model, param_grid=param_grid, n_jobs=1, cv=5,  verbose=10)
# ----> 9 grid_result = grid.fit(X_train, y_train)
#
# ~/innovation/Shyam/venv_shyam/lib/python3.6/site-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     686                 return results
#     687
# --> 688             self._run_search(evaluate_candidates)
#     689
#     690         # For multi-metric evaluation, store the best_index_, best_params_ and
#
# ~/innovation/Shyam/venv_shyam/lib/python3.6/site-packages/sklearn/model_selection/_search.py in _run_search(self, evaluate_candidates)
#    1147     def _run_search(self, evaluate_candidates):
#    1148         """Search all candidates in param_grid"""
# -> 1149         evaluate_candidates(ParameterGrid(self.param_grid))
#    1150
#    1151
#
# ~/innovation/Shyam/venv_shyam/lib/python3.6/site-packages/sklearn/model_selection/_search.py in evaluate_candidates(candidate_params)
#     665                                for parameters, (train, test)
#     666                                in product(candidate_params,
# --> 667                                           cv.split(X, y, groups)))
#     668
#     669                 if len(out) < 1:
#
# ~/innovation/Shyam/venv_shyam/lib/python3.6/site-packages/joblib/parallel.py in __call__(self, iterable)
#     919             # remaining jobs.
#     920             self._iterating = False
# --> 921             if self.dispatch_one_batch(iterator):
#     922                 self._iterating = self._original_iterator is not None
#     923
#
# ~/innovation/Shyam/venv_shyam/lib/python3.6/site-packages/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     757                 return False
#     758             else:
# --> 759                 self._dispatch(tasks)
#     760                 return True
#     761
#
# ~/innovation/Shyam/venv_shyam/lib/python3.6/site-packages/joblib/parallel.py in _dispatch(self, batch)
#     714         with self._lock:
#     715             job_idx = len(self._jobs)
# --> 716             job = self._backend.apply_async(batch, callback=cb)
#     717             # A job can complete so quickly than its callback is
#     718             # called before we get here, causing self._jobs to
#
# ~/innovation/Shyam/venv_shyam/lib/python3.6/site-packages/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     180     def apply_async(self, func, callback=None):
#     181         """Schedule a func to be run"""
# --> 182         result = ImmediateResult(func)
#     183         if callback:
#     184             callback(result)
#
# ~/innovation/Shyam/venv_shyam/lib/python3.6/site-packages/joblib/_parallel_backends.py in __init__(self, batch)
#     547         # Don't delay the application, to avoid keeping the input
#     548         # arguments in memory
# --> 549         self.results = batch()
#     550
#     551     def get(self):
#
# ~/innovation/Shyam/venv_shyam/lib/python3.6/site-packages/joblib/parallel.py in __call__(self)
#     223         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     224             return [func(*args, **kwargs)
# --> 225                     for func, args, kwargs in self.items]
#     226
#     227     def __len__(self):
#
# ~/innovation/Shyam/venv_shyam/lib/python3.6/site-packages/joblib/parallel.py in <listcomp>(.0)
#     223         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     224             return [func(*args, **kwargs)
# --> 225                     for func, args, kwargs in self.items]
#     226
#     227     def __len__(self):
#
# ~/innovation/Shyam/venv_shyam/lib/python3.6/site-packages/sklearn/model_selection/_validation.py in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, error_score)
#     514             estimator.fit(X_train, **fit_params)
#     515         else:
# --> 516             estimator.fit(X_train, y_train, **fit_params)
#     517
#     518     except Exception as e:
#
# ~/innovation/Shyam/venv_shyam/lib/python3.6/site-packages/keras/wrappers/scikit_learn.py in fit(self, x, y, sample_weight, **kwargs)
#     208         if sample_weight is not None:
#     209             kwargs['sample_weight'] = sample_weight
# --> 210         return super(KerasClassifier, self).fit(x, y, **kwargs)
#     211
#     212     def predict(self, x, **kwargs):
#
# ~/innovation/Shyam/venv_shyam/lib/python3.6/site-packages/keras/wrappers/scikit_learn.py in fit(self, x, y, **kwargs)
#     150         fit_args.update(kwargs)
#     151
# --> 152         history = self.model.fit(x, y, **fit_args)
#     153
#     154         return history
#
# ~/innovation/Shyam/venv_shyam/lib/python3.6/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#    1176                                         steps_per_epoch=steps_per_epoch,
#    1177                                         validation_steps=validation_steps,
# -> 1178                                         validation_freq=validation_freq)
#    1179
#    1180     def evaluate(self,
#
# ~/innovation/Shyam/venv_shyam/lib/python3.6/site-packages/keras/engine/training_arrays.py in fit_loop(model, fit_function, fit_inputs, out_labels, batch_size, epochs, verbose, callbacks, val_function, val_inputs, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps, validation_freq)
#     202                     ins_batch[i] = ins_batch[i].toarray()
#     203
# --> 204                 outs = fit_function(ins_batch)
#     205                 outs = to_list(outs)
#     206                 for l, o in zip(out_labels, outs):
#
# ~/innovation/Shyam/venv_shyam/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2977                     return self._legacy_call(inputs)
#    2978
# -> 2979             return self._call(inputs)
#    2980         else:
#    2981             if py_any(is_tensor(x) for x in inputs):
#
# ~/innovation/Shyam/venv_shyam/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in _call(self, inputs)
#    2935             fetched = self._callable_fn(*array_vals, run_metadata=self.run_metadata)
#    2936         else:
# -> 2937             fetched = self._callable_fn(*array_vals)
#    2938         return fetched[:len(self.outputs)]
#    2939
#
# ~/innovation/Shyam/venv_shyam/lib/python3.6/site-packages/tensorflow/python/client/session.py in __call__(self, *args, **kwargs)
#    1456         ret = tf_session.TF_SessionRunCallable(self._session._session,
#    1457                                                self._handle, args,
# -> 1458                                                run_metadata_ptr)
#    1459         if run_metadata:
#    1460           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:

# %%
# summarize results
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))

# %% [markdown]
# ### Predictions

# %%
text_pred = df_labeled.text.tolist()
t.fit_on_texts(text_pred)
post_seq_test = t.texts_to_sequences(text_pred)
x_test = pad_sequences(post_seq_test, maxlen=max_features, padding='post')
probs_test = gird.predict(x_test)

# %%
labels_test = df_labeled.label.map({'Addendum': 0, 'MSA': 1, 'SOW': 4, 'NDA': 2, 'Others': 3})
len(labels_test)
# Out:
# 1397

# %%
from snorkel.analysis import metric_score
test_acc = metric_score(golds=labels_test, preds=probs_test.argmax(axis=1), metric="accuracy")
print(f"Test Accuracy: {test_acc * 100:.1f}%")
# Out:
# Test Accuracy: 45.8%

# %% [markdown]
# ### Save Model

# %%
from keras.callbacks.callbacks import ModelCheckpoint
filepath = 'models/lstm.hdf5'
checkpointer = ModelCheckpoint(filepath, monitor='val_loss', verbose=0, save_best_only=True, save_weights_only=False, mode='auto', period=1)

# %% [markdown]
# ### Save Model Probabilities and Labels

# %%
train_pred = df_unlabeled.text.tolist()
t.fit_on_texts(train_pred)
post_seq_test = t.texts_to_sequences(train_pred)
x_train = pad_sequences(post_seq_test, maxlen=max_features, padding='post')
probs_train = model.predict(x_train)

# %%
len(probs_train)
# Out:
# 15472

# %%
labels_train = label_model.predict(L_unlabelled)
labels_train
# Out:
# array([3, 1, 3, ..., 1, 4, 4])

# %%
print(len(labels_train), len(labels_test))
print(len(probs_train), len(probs_test))
# Out:
# 15472 1397
# 15472 1397

# %%
probs_latent_train = list(zip(probs_train.tolist(), labels_train.tolist()))
probs_latent_test = list(zip(probs_test.tolist(), labels_test.tolist()))
probs_latent_test
# Out:
# [([0.2624940872192383,
#    0.27328163385391235,
#    0.08967146277427673,
#    0.10267908126115799,
#    0.27187368273735046],
#   0),
#  ([0.03332483023405075,
#    0.058378417044878006,
#    0.010397524572908878,
#    0.016984988003969193,
#    0.8809142112731934],
#   0),
#  ([0.08453257381916046,
#    0.27450767159461975,
#    0.11299096047878265,
#    0.2956554889678955,
#    0.2323133945465088],
#   0),
#  ([0.060679882764816284,
#    0.22661525011062622,
#    0.11968036741018295,
#    0.2584843039512634,
#    0.33454015851020813],
#   0),
#  ([0.18283280730247498,
#    0.09910684078931808,
#    0.08421888947486877,
#    0.23788650333881378,
#    0.3959549367427826],
#   0),
#  ([0.14197483658790588,
#    0.40013015270233154,
#    0.06504497677087784,
#    0.21624170243740082,
#    0.17660833895206451],
#   0),
#  ([0.13794468343257904,
#    0.23213954269886017,
#    0.15442854166030884,
#    0.23267491161823273,
#    0.24281232059001923],
#   0),
#  ([0.11946573108434677,
#    0.46066513657569885,
#    0.07901173084974289,
#    0.21892142295837402,
#    0.12193591892719269],
#   0),
#  ([0.1706831157207489,
#    0.34259381890296936,
#    0.13420630991458893,
#    0.2050725817680359,
#    0.14744417369365692],
#   0),
#  ([0.15438981354236603,
#    0.21577633917331696,
#    0.09663337469100952,
#    0.3096717298030853,
#    0.22352875769138336],
#   0),
#  ([0.2108936607837677,
#    0.25258156657218933,
#    0.1117326021194458,
#    0.2972507178783417,
#    0.1275414526462555],
#   0),
#  ([0.14494457840919495,
#    0.49193623661994934,
#    0.061844602227211,
#    0.11880291253328323,
#    0.18247169256210327],
#   0),
#  ([0.1621464490890503,
#    0.19319404661655426,
#    0.06762347370386124,
#    0.0809699222445488,
#    0.1845962405204773,
#    0.16326983273029327,
#    0.29168546199798584,
#    0.11063921451568604],
#   1),
#  ([0.2503181993961334,
#    0.4407673180103302,
#    0.09759210795164108,
#    0.1432965248823166,
#    0.0680258497595787],
#   1),
#  ([0.37865379452705383,
#    0.316608190536499,
#    0.0631682276725769,
#    0.03339768946170807,
#    0.20817217230796814],
#   1),
#  ([0.04713793098926544,
#    0.702331006526947,
#    0.07978417724370956,
#    0.06448694318532944,
#    0.10625997930765152],
#   1),
#  ([0.04674040526151657,
#    0.11661823093891144,
#    0.056903090327978134,
#    0.1169595792889595,
#    0.6627786755561829],
#   1),
#  ([0.06022684648633003,
#    0.6086977124214172,
#    0.09949719160795212,
#    0.18122312426567078,
#    0.05035523697733879],
#   1),
#  ([0.08877352625131607,
#    0.3841583728790283,
#    0.06963130831718445,
#    0.3653603792190552,
#    0.09207645803689957],
#   1),
#  ([0.07826044410467148,
#    0.4009508490562439,
#    0.09375451505184174,
#    0.3026335835456848,
#    0.12440057843923569],
#   1),
#  ([0.06861510127782822,
#    0.6276402473449707,
#    0.07829658687114716,
#    0.1399237960577011,
#    0.08552439510822296],
#   1),
#  ([0.017995640635490417,
#    0.8782122731208801,
#    0.034313563257455826,
#    0.019916273653507233,
#    0.04956226795911789],
#   1),
#  ([0.055523961782455444,
#    0.6371031403541565,
#    0.07171507924795151,
#    0.16805517673492432,
#    0.06760264188051224],
#   1),
#  ([0.059297144412994385,
#    0.7096694111824036,
#    0.05394737794995308,
#    0.09241562336683273,
#    0.08467040956020355],
#   1),
#  ([0.08231350779533386,
#    0.43654897809028625,
#    0.09560061246156693,
#    0.2885756492614746,
#    0.09696126729249954],
#   1),
#  ([0.16198739409446716,
#    0.5126404166221619,
#    0.050325579941272736,
#    0.09652687609195709,
#    0.17851974070072174],
#   1),
#  ([0.02042800933122635,
#    0.7981611490249634,
#    0.03428642451763153,
#    0.039160676300525665,
#    0.10796380043029785],
#   1),
#  ([0.06447470188140869,
#    0.3492834270000458,
#    0.0914277657866478,
#    0.28498274087905884,
#    0.20983140170574188],
#   1),
#  ([0.023228760808706284,
#    0.8719311356544495,
#    0.03575224056839943,
#    0.026974303647875786,
#    0.042113661766052246],
#   1),
#  ([0.16869951784610748,
#    0.22743967175483704,
#    0.08856669813394547,
#    0.3058605194091797,
#    0.20943351089954376],
#   1),
#  ...]

# %%
df_probs_train = pd.DataFrame(probs_latent_train, columns=['probabilities', 'label'])
df_probs_test = pd.DataFrame(probs_latent_test, columns=['probabilities', 'label'])

# %%
df_probs_test.head()
# Out:
#                                        probabilities  label
# 0  [0.2624940872192383, 0.27328163385391235, 0.08...      0
# 1  [0.03332483023405075, 0.058378417044878006, 0....      0
# 2  [0.08453257381916046, 0.27450767159461975, 0.1...      0
# 3  [0.060679882764816284, 0.22661525011062622, 0....      0
# 4  [0.18283280730247498, 0.09910684078931808, 0.0...      0

# %%
df_probs_train.to_csv('probabilities_train.csv', index = None)
df_probs_test.to_csv('probabilities_test.csv', index = None)
